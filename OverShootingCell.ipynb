# %% [markdown]
# <a href="https://colab.research.google.com/github/Salahbendary/Performance-Analysis-and-Prediction-of-LTE-Networks-Using-AI/blob/main/OverShootingCell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overshooting Problem

# %%
import pandas as pd
import numpy as np

# %%
overShootingCell = pd.read_csv('/content/overShootingCell.csv', encoding='ISO-8859-1')

# %%
overShootingCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 539 non-null    int64
#  1   Time                                539 non-null    object
#  2   Drive_Lat                           539 non-null    float64
#  3   Drive_Lon                           539 non-null    float64
#  4   Cell_lat                            539 non-null    float64
#  5   Cell_lon                            539 non-null    float64
#  6   Dis_Serving                         539 non-null    float64
#  7   Serving_Cell                        539 non-null    int64
#  8   Serving Cell RSRP                   539 non-null    float64
#  9   Serving Cell RSRQ                   539 non-null    float64
#  10  RS SINR Carrier 1                   539 non-null    float64
#  11  Serving Cell Channel RSSI           539 non-null    float64
#  12  CQI                                 539 non-null    int64
#  13  Throughput DL                       539 non-null    float64
#  14  Throughput UL                       539 non-null    float64
#  15  Rank Indicator                      539 non-null    int64
#  16  latitude_Cell_N1                    539 non-null    float64
#  17  longitude_Cell_N1                   539 non-null    float64
#  18  Distance_N1                         539 non-null    float64
#  19  Neighbor Cell Identity: N1          539 non-null    int64
#  20  Neighbor Cell RSRP: N1              539 non-null    float64
#  21  Neighbor Cell RSRQ: N1              539 non-null    float64
#  22  latitude_Cell_N2                    539 non-null    float64
#  23  longitude_Cell_N2                   539 non-null    float64
#  24  Distance_N2                         539 non-null    float64
#  25  Neighbor Cell Identity: N2          539 non-null    int64
#  26  Neighbor Cell RSRP: N2              539 non-null    float64
#  27  Neighbor Cell RSRQ: N2              539 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            539 non-null    float64
#  29  MAC UL Throughput (kbps)            539 non-null    float64
#  30  RLC Throughput DL (kbps)            539 non-null    float64
#  31  RLC Throughput UL (kbps)            539 non-null    float64
#  32  PDCCH Downlink Grant Count Current  539 non-null    float64
#  33  PDCCH Uplink Grant Count Current    539 non-null    float64
#  34  States                              539 non-null    object
# dtypes: float64(27), int64(6), object(2)
# memory usage: 147.5+ KB

# %%
overShootingCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
overShootingCell.head(2)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0    8  10:46:15 PM  30.037993  30.976972  30.04072  30.98725     1.034814
# 1   10  10:46:19 PM  30.037947  30.976934  30.04072  30.98725     1.039744
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           285         -85.900002              -10.7                5.1
# 1           285         -98.800003              -16.9               -0.3
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -55.200001    7    7094.962703     638.419165
# 1                 -56.099998    7     280.829987      47.860001
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1          30.04055          30.978168     0.306743
# 1               1          30.04055          30.978168     0.312833
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                          76              -89.800003              -16.299999
# 1                          76              -93.900002              -14.300000
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0         30.033771          30.982752     0.728044
# 1         30.039874          30.971949     0.525545
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                         320              -92.099998              -17.299999
# 1                         157              -99.699997              -19.500000
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                      0.00                122.982238
# 1                      2.85                 11.700000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1                  0.100000                  1.130000
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           57.000000                         85.000000
#
#                          States
# 0  serving cell is overshooting
# 1  serving cell is overshooting

# %%
overShootingCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 539 non-null    int64
#  1   Time                                539 non-null    object
#  2   Drive_Lat                           539 non-null    float64
#  3   Drive_Lon                           539 non-null    float64
#  4   Cell_lat                            539 non-null    float64
#  5   Cell_lon                            539 non-null    float64
#  6   Dis_Serving                         539 non-null    float64
#  7   Serving_Cell                        539 non-null    int64
#  8   Serving Cell RSRP                   539 non-null    float64
#  9   Serving Cell RSRQ                   539 non-null    float64
#  10  RS SINR Carrier 1                   539 non-null    float64
#  11  Serving Cell Channel RSSI           539 non-null    float64
#  12  CQI                                 539 non-null    int64
#  13  Throughput DL                       539 non-null    float64
#  14  Throughput UL                       539 non-null    float64
#  15  Rank Indicator                      539 non-null    int64
#  16  latitude_Cell_N1                    539 non-null    float64
#  17  longitude_Cell_N1                   539 non-null    float64
#  18  Distance_N1                         539 non-null    float64
#  19  Neighbor Cell Identity: N1          539 non-null    int64
#  20  Neighbor Cell RSRP: N1              539 non-null    float64
#  21  Neighbor Cell RSRQ: N1              539 non-null    float64
#  22  latitude_Cell_N2                    539 non-null    float64
#  23  longitude_Cell_N2                   539 non-null    float64
#  24  Distance_N2                         539 non-null    float64
#  25  Neighbor Cell Identity: N2          539 non-null    int64
#  26  Neighbor Cell RSRP: N2              539 non-null    float64
#  27  Neighbor Cell RSRQ: N2              539 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            539 non-null    float64
#  29  MAC UL Throughput (kbps)            539 non-null    float64
#  30  RLC Throughput DL (kbps)            539 non-null    float64
#  31  RLC Throughput UL (kbps)            539 non-null    float64
#  32  PDCCH Downlink Grant Count Current  539 non-null    float64
#  33  PDCCH Uplink Grant Count Current    539 non-null    float64
#  34  States                              539 non-null    object
# dtypes: float64(27), int64(6), object(2)
# memory usage: 147.5+ KB

# %%
overShootingCell.describe()
# Out:
#                 ï»¿   Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  \
# count    539.000000  539.000000  539.000000  539.000000  539.000000
# mean    7562.627087   30.040612   30.975187   30.026577   30.969532
# std     4164.816779    0.004096    0.010343    0.019594    0.011569
# min        8.000000   30.023673   30.960086   29.982552   30.939990
# 25%     4428.500000   30.038932   30.967905   30.008730   30.963140
# 50%     7738.000000   30.041265   30.976597   30.031055   30.974717
# 75%    10815.000000   30.042771   30.978135   30.045278   30.974717
# max    14811.000000   30.053218   31.015539   30.058100   31.032543
#
#        Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count   539.000000    539.000000         539.000000         539.000000
# mean      2.529759    185.693878         -82.837106         -16.852319
# std       2.056400     85.404684           9.179640           3.380439
# min       0.358410     13.000000        -106.000000         -27.400000
# 25%       0.762909    145.000000         -89.900002         -19.200001
# 50%       3.332039    191.000000         -82.199997         -16.500000
# 75%       3.757648    191.000000         -75.599998         -14.300000
# max       9.906187    501.000000         -62.099998          -9.800000
#
#        RS SINR Carrier 1  Serving Cell Channel RSSI         CQI  \
# count         539.000000                 539.000000  539.000000
# mean            1.015196                 -47.763080    7.063080
# std             4.860584                   7.208916    1.082005
# min            -9.200000                 -67.099998    4.000000
# 25%            -2.500000                 -53.049999    7.000000
# 50%             0.800000                 -47.299999    7.000000
# 75%             4.000000                 -42.000000    7.000000
# max            16.100000                 -26.600000   13.000000
#
#        Throughput DL  Throughput UL  Rank Indicator  latitude_Cell_N1  \
# count     539.000000     539.000000      539.000000        539.000000
# mean     5715.091748     433.390012        1.098330         30.039652
# std      3843.695585     354.021400        0.298037          0.005977
# min         0.120000       0.700000        1.000000         29.975623
# 25%      2750.960083     185.415001        1.000000         30.039874
# 50%      5768.580078     350.260010        1.000000         30.040550
# 75%      8156.135009     619.959991        1.000000         30.041362
# max     26172.689450    1688.670044        2.000000         30.046500
#
#        longitude_Cell_N1  Distance_N1  Neighbor Cell Identity: N1  \
# count         539.000000   539.000000                  539.000000
# mean           30.975457     0.363302                  168.734694
# std             0.009975     0.662248                  138.798583
# min            30.959722     0.030734                   12.000000
# 25%            30.969330     0.167032                   76.000000
# 50%            30.978168     0.253858                   77.000000
# 75%            30.978168     0.362078                  225.000000
# max            31.017482     8.612168                  502.000000
#
#        Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  latitude_Cell_N2  \
# count              539.000000              539.000000        539.000000
# mean               -83.097217              -16.913173         30.038388
# std                  9.048749                3.694519          0.009197
# min               -102.400002              -30.000000         29.975623
# 25%                -89.699997              -18.400000         30.039874
# 50%                -83.199997              -16.100000         30.040550
# 75%                -76.500000              -14.500000         30.040635
# max                -59.799999               -9.400000         30.055470
#
#        longitude_Cell_N2  Distance_N2  Neighbor Cell Identity: N2  \
# count         539.000000   539.000000                  539.000000
# mean           30.975286     0.515862                  187.946197
# std             0.009664     1.115224                  141.003068
# min            30.959722     0.030734                   12.000000
# 25%            30.969330     0.184135                   75.000000
# 50%            30.978168     0.284347                  156.000000
# 75%            30.978168     0.468675                  320.000000
# max            31.021740     8.722353                  502.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count              539.000000              539.000000
# mean               -86.815770              -20.694620
# std                  8.610599                4.306383
# min               -108.099998              -30.000000
# 25%                -93.250000              -23.550000
# 50%                -86.699997              -20.000000
# 75%                -80.549999              -17.299999
# max                -65.199997              -11.100000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count                539.000000                539.000000
# mean                  15.749202                 95.584859
# std                    9.213560                 72.524371
# min                    0.000000                  0.000000
# 25%                   11.295000                 45.039999
# 50%                   14.100000                 86.180000
# 75%                   19.890000                132.495003
# max                  100.000000                415.220001
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count                539.000000                539.000000
# mean                5643.477147                102.569281
# std                 5592.416732                 97.713511
# min                    0.000000                  0.000000
# 25%                 1785.369995                 33.350000
# 50%                 4557.649902                 92.129997
# 75%                 7119.502785                125.701727
# max                33996.589840                749.630005
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                          539.000000                        539.000000
# mean                          1028.015833                        520.762026
# std                            581.465202                        445.587307
# min                              0.000000                          0.000000
# 25%                            695.000000                        189.000000
# 50%                           1107.000000                        411.000000
# 75%                           1431.500000                        738.500000
# max                           3679.000000                       2008.000000

# %%
overShootingCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
FinaloverShootingCell = overShootingCell.dropna(axis=0)

# %%
FinaloverShootingCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 539 non-null    int64
#  1   Time                                539 non-null    object
#  2   Drive_Lat                           539 non-null    float64
#  3   Drive_Lon                           539 non-null    float64
#  4   Cell_lat                            539 non-null    float64
#  5   Cell_lon                            539 non-null    float64
#  6   Dis_Serving                         539 non-null    float64
#  7   Serving_Cell                        539 non-null    int64
#  8   Serving Cell RSRP                   539 non-null    float64
#  9   Serving Cell RSRQ                   539 non-null    float64
#  10  RS SINR Carrier 1                   539 non-null    float64
#  11  Serving Cell Channel RSSI           539 non-null    float64
#  12  CQI                                 539 non-null    int64
#  13  Throughput DL                       539 non-null    float64
#  14  Throughput UL                       539 non-null    float64
#  15  Rank Indicator                      539 non-null    int64
#  16  latitude_Cell_N1                    539 non-null    float64
#  17  longitude_Cell_N1                   539 non-null    float64
#  18  Distance_N1                         539 non-null    float64
#  19  Neighbor Cell Identity: N1          539 non-null    int64
#  20  Neighbor Cell RSRP: N1              539 non-null    float64
#  21  Neighbor Cell RSRQ: N1              539 non-null    float64
#  22  latitude_Cell_N2                    539 non-null    float64
#  23  longitude_Cell_N2                   539 non-null    float64
#  24  Distance_N2                         539 non-null    float64
#  25  Neighbor Cell Identity: N2          539 non-null    int64
#  26  Neighbor Cell RSRP: N2              539 non-null    float64
#  27  Neighbor Cell RSRQ: N2              539 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            539 non-null    float64
#  29  MAC UL Throughput (kbps)            539 non-null    float64
#  30  RLC Throughput DL (kbps)            539 non-null    float64
#  31  RLC Throughput UL (kbps)            539 non-null    float64
#  32  PDCCH Downlink Grant Count Current  539 non-null    float64
#  33  PDCCH Uplink Grant Count Current    539 non-null    float64
#  34  States                              539 non-null    object
# dtypes: float64(27), int64(6), object(2)
# memory usage: 147.5+ KB

# %%
FinaloverShootingCell.describe()
# Out:
#                 ï»¿   Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  \
# count    539.000000  539.000000  539.000000  539.000000  539.000000
# mean    7562.627087   30.040612   30.975187   30.026577   30.969532
# std     4164.816779    0.004096    0.010343    0.019594    0.011569
# min        8.000000   30.023673   30.960086   29.982552   30.939990
# 25%     4428.500000   30.038932   30.967905   30.008730   30.963140
# 50%     7738.000000   30.041265   30.976597   30.031055   30.974717
# 75%    10815.000000   30.042771   30.978135   30.045278   30.974717
# max    14811.000000   30.053218   31.015539   30.058100   31.032543
#
#        Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count   539.000000    539.000000         539.000000         539.000000
# mean      2.529759    185.693878         -82.837106         -16.852319
# std       2.056400     85.404684           9.179640           3.380439
# min       0.358410     13.000000        -106.000000         -27.400000
# 25%       0.762909    145.000000         -89.900002         -19.200001
# 50%       3.332039    191.000000         -82.199997         -16.500000
# 75%       3.757648    191.000000         -75.599998         -14.300000
# max       9.906187    501.000000         -62.099998          -9.800000
#
#        RS SINR Carrier 1  Serving Cell Channel RSSI         CQI  \
# count         539.000000                 539.000000  539.000000
# mean            1.015196                 -47.763080    7.063080
# std             4.860584                   7.208916    1.082005
# min            -9.200000                 -67.099998    4.000000
# 25%            -2.500000                 -53.049999    7.000000
# 50%             0.800000                 -47.299999    7.000000
# 75%             4.000000                 -42.000000    7.000000
# max            16.100000                 -26.600000   13.000000
#
#        Throughput DL  Throughput UL  Rank Indicator  latitude_Cell_N1  \
# count     539.000000     539.000000      539.000000        539.000000
# mean     5715.091748     433.390012        1.098330         30.039652
# std      3843.695585     354.021400        0.298037          0.005977
# min         0.120000       0.700000        1.000000         29.975623
# 25%      2750.960083     185.415001        1.000000         30.039874
# 50%      5768.580078     350.260010        1.000000         30.040550
# 75%      8156.135009     619.959991        1.000000         30.041362
# max     26172.689450    1688.670044        2.000000         30.046500
#
#        longitude_Cell_N1  Distance_N1  Neighbor Cell Identity: N1  \
# count         539.000000   539.000000                  539.000000
# mean           30.975457     0.363302                  168.734694
# std             0.009975     0.662248                  138.798583
# min            30.959722     0.030734                   12.000000
# 25%            30.969330     0.167032                   76.000000
# 50%            30.978168     0.253858                   77.000000
# 75%            30.978168     0.362078                  225.000000
# max            31.017482     8.612168                  502.000000
#
#        Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  latitude_Cell_N2  \
# count              539.000000              539.000000        539.000000
# mean               -83.097217              -16.913173         30.038388
# std                  9.048749                3.694519          0.009197
# min               -102.400002              -30.000000         29.975623
# 25%                -89.699997              -18.400000         30.039874
# 50%                -83.199997              -16.100000         30.040550
# 75%                -76.500000              -14.500000         30.040635
# max                -59.799999               -9.400000         30.055470
#
#        longitude_Cell_N2  Distance_N2  Neighbor Cell Identity: N2  \
# count         539.000000   539.000000                  539.000000
# mean           30.975286     0.515862                  187.946197
# std             0.009664     1.115224                  141.003068
# min            30.959722     0.030734                   12.000000
# 25%            30.969330     0.184135                   75.000000
# 50%            30.978168     0.284347                  156.000000
# 75%            30.978168     0.468675                  320.000000
# max            31.021740     8.722353                  502.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count              539.000000              539.000000
# mean               -86.815770              -20.694620
# std                  8.610599                4.306383
# min               -108.099998              -30.000000
# 25%                -93.250000              -23.550000
# 50%                -86.699997              -20.000000
# 75%                -80.549999              -17.299999
# max                -65.199997              -11.100000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count                539.000000                539.000000
# mean                  15.749202                 95.584859
# std                    9.213560                 72.524371
# min                    0.000000                  0.000000
# 25%                   11.295000                 45.039999
# 50%                   14.100000                 86.180000
# 75%                   19.890000                132.495003
# max                  100.000000                415.220001
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count                539.000000                539.000000
# mean                5643.477147                102.569281
# std                 5592.416732                 97.713511
# min                    0.000000                  0.000000
# 25%                 1785.369995                 33.350000
# 50%                 4557.649902                 92.129997
# 75%                 7119.502785                125.701727
# max                33996.589840                749.630005
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                          539.000000                        539.000000
# mean                          1028.015833                        520.762026
# std                            581.465202                        445.587307
# min                              0.000000                          0.000000
# 25%                            695.000000                        189.000000
# 50%                           1107.000000                        411.000000
# 75%                           1431.500000                        738.500000
# max                           3679.000000                       2008.000000

# %%
FinaloverShootingCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
FinaloverShootingCell.head(5)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon   Cell_lat   Cell_lon  Dis_Serving  \
# 0    8  10:46:15 PM  30.037993  30.976972  30.040720  30.987250     1.034814
# 1   10  10:46:19 PM  30.037947  30.976934  30.040720  30.987250     1.039744
# 2  150  10:51:11 PM  30.040812  30.963844  30.045278  30.959722     0.635650
# 3  151  10:51:13 PM  30.040862  30.963877  30.045278  30.959722     0.633258
# 4  152  10:51:15 PM  30.040901  30.963906  30.045278  30.959722     0.631742
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           285         -85.900002         -10.700000                5.1
# 1           285         -98.800003         -16.900000               -0.3
# 2            86         -81.500000         -13.300000               -0.2
# 3            86         -83.900002         -15.400000               -1.9
# 4            86         -88.300003         -18.799999               -6.2
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -55.200001    7    7094.962703     638.419165
# 1                 -56.099998    7     280.829987      47.860001
# 2                 -46.599998    7     476.700012     114.040001
# 3                 -48.000000    7    9614.290039     426.769989
# 4                 -46.299999    7    7730.509766     638.419165
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1         30.040550          30.978168     0.306743
# 1               1         30.040550          30.978168     0.312833
# 2               1         30.041362          30.963813     0.061258
# 3               1         30.041362          30.963813     0.055890
# 4               1         30.041362          30.963813     0.052065
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                          76              -89.800003              -16.299999
# 1                          76              -93.900002              -14.300000
# 2                         420              -82.099998              -11.700000
# 3                         420              -83.000000              -10.800000
# 4                         420              -83.599998              -11.800000
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0         30.033771          30.982752     0.728044
# 1         30.039874          30.971949     0.525545
# 2         30.041362          30.963813     0.061258
# 3         30.041362          30.963813     0.055890
# 4         30.041362          30.963813     0.052065
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                         320              -92.099998              -17.299999
# 1                         157              -99.699997              -19.500000
# 2                         422              -88.400002              -16.200001
# 3                         422              -89.199997              -16.400000
# 4                         422              -89.199997              -16.700001
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                      0.00                122.982238
# 1                      2.85                 11.700000
# 2                      0.57                 55.509998
# 3                      9.52                122.790001
# 4                     10.21                124.800003
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1                  0.100000                  1.130000
# 2                192.470001                 54.009998
# 3               7119.502785                125.701727
# 4               4163.439941                125.701727
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           57.000000                         85.000000
# 2                           49.000000                        158.000000
# 3                          361.000000                        379.000000
# 4                          116.000000                        101.000000
#
#                          States
# 0  serving cell is overshooting
# 1  serving cell is overshooting
# 2  serving cell is overshooting
# 3  serving cell is overshooting
# 4  serving cell is overshooting

# %%
FinaloverShootingCell.to_csv('FinaloverShootingCellFiltered.csv', index=True)

# %% [markdown]
# Preparation

# %%
# data mining libaries
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, GridSearchCV, learning_curve
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sn
import matplotlib.pyplot as plt

#plot libaries
import plotly
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True) # to show plots in notebook

# online plotly
#from plotly.plotly import plot, iplot
#plotly.tools.set_credentials_file(username='XXXXXXXXXXXXXXX', api_key='XXXXXXXXXXXXXXX')

# offline plotly
from plotly.offline import plot, iplot

# do not show any warnings
import warnings
warnings.filterwarnings('ignore')

SEED = 42 # specify seed for reproducable results
pd.set_option('display.max_columns', None) # prevents abbreviation (with '...') of columns in prints
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# DATASET ANALYSIS

# %%
# load the dataset
df = pd.read_csv('FinaloverShootingCellFiltered.csv')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# df = df.query('Throughput > 10000')
print("The dataset has %d rows and %d columns" % df.shape)
# Feature Selection
# df = df[['Serving Cell RSRP','Serving Cell Channel RSSI','Throughput UL','RLC Throughput DL (kbps)', 'MAC UL Throughput (kbps)', 'RS SINR Carrier 1', 'Serving Cell RSRQ','Throughput']]
# Out:
# The dataset has 539 rows and 36 columns

# %%
# df = df [['Serving Cell RSRP','Serving Cell Channel RSSI','Throughput UL','RLC Throughput DL (kbps)', 'MAC UL Throughput (kbps)', 'RS SINR Carrier 1', 'Serving Cell RSRQ','Throughput','PDSCH BLER Carrier 1 (%)','PDCCH Downlink Grant Count Current','PDCCH Uplink Grant Count Current','RLC Throughput UL (kbps)']]

# %%
df = df.drop('Unnamed: 0',axis=True)

# %%
feature_selection = df[['Serving_Cell','Serving Cell RSRP','Serving Cell RSRQ','Serving Cell Channel RSSI','Throughput DL','Throughput UL']]
import seaborn as sns
# Correlation Score
plt.figure(figsize=(12, 10))
correlation_matrix = feature_selection.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, cmap='coolwarm', annot=True,linewidths=0.01, )
plt.title("Correlation Matrix", size=25)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.describe()
# Out:
#                 ï»¿   Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  \
# count    539.000000  539.000000  539.000000  539.000000  539.000000
# mean    7562.627087   30.040612   30.975187   30.026577   30.969532
# std     4164.816779    0.004096    0.010343    0.019594    0.011569
# min        8.000000   30.023673   30.960086   29.982552   30.939990
# 25%     4428.500000   30.038932   30.967905   30.008730   30.963140
# 50%     7738.000000   30.041265   30.976597   30.031055   30.974717
# 75%    10815.000000   30.042771   30.978135   30.045278   30.974717
# max    14811.000000   30.053218   31.015539   30.058100   31.032543
#
#        Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count   539.000000    539.000000         539.000000         539.000000
# mean      2.529759    185.693878         -82.837106         -16.852319
# std       2.056400     85.404684           9.179640           3.380439
# min       0.358410     13.000000        -106.000000         -27.400000
# 25%       0.762909    145.000000         -89.900002         -19.200001
# 50%       3.332039    191.000000         -82.199997         -16.500000
# 75%       3.757648    191.000000         -75.599998         -14.300000
# max       9.906187    501.000000         -62.099998          -9.800000
#
#        RS SINR Carrier 1  Serving Cell Channel RSSI         CQI  \
# count         539.000000                 539.000000  539.000000
# mean            1.015196                 -47.763080    7.063080
# std             4.860584                   7.208916    1.082005
# min            -9.200000                 -67.099998    4.000000
# 25%            -2.500000                 -53.049999    7.000000
# 50%             0.800000                 -47.299999    7.000000
# 75%             4.000000                 -42.000000    7.000000
# max            16.100000                 -26.600000   13.000000
#
#        Throughput DL  Throughput UL  Rank Indicator  latitude_Cell_N1  \
# count     539.000000     539.000000      539.000000        539.000000
# mean     5715.091748     433.390012        1.098330         30.039652
# std      3843.695585     354.021400        0.298037          0.005977
# min         0.120000       0.700000        1.000000         29.975623
# 25%      2750.960083     185.415001        1.000000         30.039874
# 50%      5768.580078     350.260010        1.000000         30.040550
# 75%      8156.135009     619.959991        1.000000         30.041362
# max     26172.689450    1688.670044        2.000000         30.046500
#
#        longitude_Cell_N1  Distance_N1  Neighbor Cell Identity: N1  \
# count         539.000000   539.000000                  539.000000
# mean           30.975457     0.363302                  168.734694
# std             0.009975     0.662248                  138.798583
# min            30.959722     0.030734                   12.000000
# 25%            30.969330     0.167032                   76.000000
# 50%            30.978168     0.253858                   77.000000
# 75%            30.978168     0.362078                  225.000000
# max            31.017482     8.612168                  502.000000
#
#        Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  latitude_Cell_N2  \
# count              539.000000              539.000000        539.000000
# mean               -83.097217              -16.913173         30.038388
# std                  9.048749                3.694519          0.009197
# min               -102.400002              -30.000000         29.975623
# 25%                -89.699997              -18.400000         30.039874
# 50%                -83.199997              -16.100000         30.040550
# 75%                -76.500000              -14.500000         30.040635
# max                -59.799999               -9.400000         30.055470
#
#        longitude_Cell_N2  Distance_N2  Neighbor Cell Identity: N2  \
# count         539.000000   539.000000                  539.000000
# mean           30.975286     0.515862                  187.946197
# std             0.009664     1.115224                  141.003068
# min            30.959722     0.030734                   12.000000
# 25%            30.969330     0.184135                   75.000000
# 50%            30.978168     0.284347                  156.000000
# 75%            30.978168     0.468675                  320.000000
# max            31.021740     8.722353                  502.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count              539.000000              539.000000
# mean               -86.815770              -20.694620
# std                  8.610599                4.306383
# min               -108.099998              -30.000000
# 25%                -93.250000              -23.550000
# 50%                -86.699997              -20.000000
# 75%                -80.549999              -17.299999
# max                -65.199997              -11.100000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count                539.000000                539.000000
# mean                  15.749202                 95.584859
# std                    9.213560                 72.524371
# min                    0.000000                  0.000000
# 25%                   11.295000                 45.039999
# 50%                   14.100000                 86.180000
# 75%                   19.890000                132.495003
# max                  100.000000                415.220001
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count                539.000000                539.000000
# mean                5643.477147                102.569281
# std                 5592.416732                 97.713511
# min                    0.000000                  0.000000
# 25%                 1785.369995                 33.350000
# 50%                 4557.649902                 92.129997
# 75%                 7119.502785                125.701727
# max                33996.589840                749.630005
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                          539.000000                        539.000000
# mean                          1028.015833                        520.762026
# std                            581.465202                        445.587307
# min                              0.000000                          0.000000
# 25%                            695.000000                        189.000000
# 50%                           1107.000000                        411.000000
# 75%                           1431.500000                        738.500000
# max                           3679.000000                       2008.000000

# %%
df.columns
# Out:
# Index(['ï»¿', 'Time', 'Drive_Lat', 'Drive_Lon', 'Cell_lat', 'Cell_lon',
#        'Dis_Serving', 'Serving_Cell', 'Serving Cell RSRP', 'Serving Cell RSRQ',
#        'RS SINR Carrier 1', 'Serving Cell Channel RSSI', 'CQI',
#        'Throughput DL', 'Throughput UL', 'Rank Indicator', 'latitude_Cell_N1',
#        'longitude_Cell_N1', 'Distance_N1', 'Neighbor Cell Identity: N1',
#        'Neighbor Cell RSRP: N1', 'Neighbor Cell RSRQ: N1', 'latitude_Cell_N2',
#        'longitude_Cell_N2', 'Distance_N2', 'Neighbor Cell Identity: N2',
#        'Neighbor Cell RSRP: N2', 'Neighbor Cell RSRQ: N2',
#        'PDSCH BLER Carrier 1 (%)', 'MAC UL Throughput (kbps)',
#        'RLC Throughput DL (kbps)', 'RLC Throughput UL (kbps)',
#        'PDCCH Downlink Grant Count Current',
#        'PDCCH Uplink Grant Count Current', 'States'],
#       dtype='object')

# %%
count_nan = df.isna().sum().sum()
print ('Count of NaN/NULL values: ' + str(count_nan))
# Out:
# Count of NaN/NULL values: 0

# %%
df = df.dropna()

# %%
df.head(3)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon   Cell_lat   Cell_lon  Dis_Serving  \
# 0    8  10:46:15 PM  30.037993  30.976972  30.040720  30.987250     1.034814
# 1   10  10:46:19 PM  30.037947  30.976934  30.040720  30.987250     1.039744
# 2  150  10:51:11 PM  30.040812  30.963844  30.045278  30.959722     0.635650
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           285         -85.900002              -10.7                5.1
# 1           285         -98.800003              -16.9               -0.3
# 2            86         -81.500000              -13.3               -0.2
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -55.200001    7    7094.962703     638.419165
# 1                 -56.099998    7     280.829987      47.860001
# 2                 -46.599998    7     476.700012     114.040001
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1         30.040550          30.978168     0.306743
# 1               1         30.040550          30.978168     0.312833
# 2               1         30.041362          30.963813     0.061258
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                          76              -89.800003              -16.299999
# 1                          76              -93.900002              -14.300000
# 2                         420              -82.099998              -11.700000
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0         30.033771          30.982752     0.728044
# 1         30.039874          30.971949     0.525545
# 2         30.041362          30.963813     0.061258
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                         320              -92.099998              -17.299999
# 1                         157              -99.699997              -19.500000
# 2                         422              -88.400002              -16.200001
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                      0.00                122.982238
# 1                      2.85                 11.700000
# 2                      0.57                 55.509998
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1                  0.100000                  1.130000
# 2                192.470001                 54.009998
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           57.000000                         85.000000
# 2                           49.000000                        158.000000
#
#                          States
# 0  serving cell is overshooting
# 1  serving cell is overshooting
# 2  serving cell is overshooting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 539 non-null    int64
#  1   Time                                539 non-null    object
#  2   Drive_Lat                           539 non-null    float64
#  3   Drive_Lon                           539 non-null    float64
#  4   Cell_lat                            539 non-null    float64
#  5   Cell_lon                            539 non-null    float64
#  6   Dis_Serving                         539 non-null    float64
#  7   Serving_Cell                        539 non-null    int64
#  8   Serving Cell RSRP                   539 non-null    float64
#  9   Serving Cell RSRQ                   539 non-null    float64
#  10  RS SINR Carrier 1                   539 non-null    float64
#  11  Serving Cell Channel RSSI           539 non-null    float64
#  12  CQI                                 539 non-null    int64
#  13  Throughput DL                       539 non-null    float64
#  14  Throughput UL                       539 non-null    float64
#  15  Rank Indicator                      539 non-null    int64
#  16  latitude_Cell_N1                    539 non-null    float64
#  17  longitude_Cell_N1                   539 non-null    float64
#  18  Distance_N1                         539 non-null    float64
#  19  Neighbor Cell Identity: N1          539 non-null    int64
#  20  Neighbor Cell RSRP: N1              539 non-null    float64
#  21  Neighbor Cell RSRQ: N1              539 non-null    float64
#  22  latitude_Cell_N2                    539 non-null    float64
#  23  longitude_Cell_N2                   539 non-null    float64
#  24  Distance_N2                         539 non-null    float64
#  25  Neighbor Cell Identity: N2          539 non-null    int64
#  26  Neighbor Cell RSRP: N2              539 non-null    float64
#  27  Neighbor Cell RSRQ: N2              539 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            539 non-null    float64
#  29  MAC UL Throughput (kbps)            539 non-null    float64
#  30  RLC Throughput DL (kbps)            539 non-null    float64
#  31  RLC Throughput UL (kbps)            539 non-null    float64
#  32  PDCCH Downlink Grant Count Current  539 non-null    float64
#  33  PDCCH Uplink Grant Count Current    539 non-null    float64
#  34  States                              539 non-null    object
# dtypes: float64(27), int64(6), object(2)
# memory usage: 147.5+ KB

# %%
df.drop(['ï»¿'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Time                                539 non-null    object
#  1   Drive_Lat                           539 non-null    float64
#  2   Drive_Lon                           539 non-null    float64
#  3   Cell_lat                            539 non-null    float64
#  4   Cell_lon                            539 non-null    float64
#  5   Dis_Serving                         539 non-null    float64
#  6   Serving_Cell                        539 non-null    int64
#  7   Serving Cell RSRP                   539 non-null    float64
#  8   Serving Cell RSRQ                   539 non-null    float64
#  9   RS SINR Carrier 1                   539 non-null    float64
#  10  Serving Cell Channel RSSI           539 non-null    float64
#  11  CQI                                 539 non-null    int64
#  12  Throughput DL                       539 non-null    float64
#  13  Throughput UL                       539 non-null    float64
#  14  Rank Indicator                      539 non-null    int64
#  15  latitude_Cell_N1                    539 non-null    float64
#  16  longitude_Cell_N1                   539 non-null    float64
#  17  Distance_N1                         539 non-null    float64
#  18  Neighbor Cell Identity: N1          539 non-null    int64
#  19  Neighbor Cell RSRP: N1              539 non-null    float64
#  20  Neighbor Cell RSRQ: N1              539 non-null    float64
#  21  latitude_Cell_N2                    539 non-null    float64
#  22  longitude_Cell_N2                   539 non-null    float64
#  23  Distance_N2                         539 non-null    float64
#  24  Neighbor Cell Identity: N2          539 non-null    int64
#  25  Neighbor Cell RSRP: N2              539 non-null    float64
#  26  Neighbor Cell RSRQ: N2              539 non-null    float64
#  27  PDSCH BLER Carrier 1 (%)            539 non-null    float64
#  28  MAC UL Throughput (kbps)            539 non-null    float64
#  29  RLC Throughput DL (kbps)            539 non-null    float64
#  30  RLC Throughput UL (kbps)            539 non-null    float64
#  31  PDCCH Downlink Grant Count Current  539 non-null    float64
#  32  PDCCH Uplink Grant Count Current    539 non-null    float64
#  33  States                              539 non-null    object
# dtypes: float64(27), int64(5), object(2)
# memory usage: 143.3+ KB

# %%
def preprocess_data(df):
    pre_df = df.copy()
    return pre_df

# %%
pre_df = preprocess_data(df)
pre_df.head(3)
# Out:
#           Time  Drive_Lat  Drive_Lon   Cell_lat   Cell_lon  Dis_Serving  \
# 0  10:46:15 PM  30.037993  30.976972  30.040720  30.987250     1.034814
# 1  10:46:19 PM  30.037947  30.976934  30.040720  30.987250     1.039744
# 2  10:51:11 PM  30.040812  30.963844  30.045278  30.959722     0.635650
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           285         -85.900002              -10.7                5.1
# 1           285         -98.800003              -16.9               -0.3
# 2            86         -81.500000              -13.3               -0.2
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -55.200001    7    7094.962703     638.419165
# 1                 -56.099998    7     280.829987      47.860001
# 2                 -46.599998    7     476.700012     114.040001
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1         30.040550          30.978168     0.306743
# 1               1         30.040550          30.978168     0.312833
# 2               1         30.041362          30.963813     0.061258
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                          76              -89.800003              -16.299999
# 1                          76              -93.900002              -14.300000
# 2                         420              -82.099998              -11.700000
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0         30.033771          30.982752     0.728044
# 1         30.039874          30.971949     0.525545
# 2         30.041362          30.963813     0.061258
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                         320              -92.099998              -17.299999
# 1                         157              -99.699997              -19.500000
# 2                         422              -88.400002              -16.200001
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                      0.00                122.982238
# 1                      2.85                 11.700000
# 2                      0.57                 55.509998
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1                  0.100000                  1.130000
# 2                192.470001                 54.009998
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           57.000000                         85.000000
# 2                           49.000000                        158.000000
#
#                          States
# 0  serving cell is overshooting
# 1  serving cell is overshooting
# 2  serving cell is overshooting

# %%
print("The dataset has %d rows and %d columns." % pre_df.shape)
# Out:
# The dataset has 539 rows and 34 columns.

# %%
pre_df.describe()
# Out:
#         Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  Dis_Serving  \
# count  539.000000  539.000000  539.000000  539.000000   539.000000
# mean    30.040612   30.975187   30.026577   30.969532     2.529759
# std      0.004096    0.010343    0.019594    0.011569     2.056400
# min     30.023673   30.960086   29.982552   30.939990     0.358410
# 25%     30.038932   30.967905   30.008730   30.963140     0.762909
# 50%     30.041265   30.976597   30.031055   30.974717     3.332039
# 75%     30.042771   30.978135   30.045278   30.974717     3.757648
# max     30.053218   31.015539   30.058100   31.032543     9.906187
#
#        Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# count    539.000000         539.000000         539.000000         539.000000
# mean     185.693878         -82.837106         -16.852319           1.015196
# std       85.404684           9.179640           3.380439           4.860584
# min       13.000000        -106.000000         -27.400000          -9.200000
# 25%      145.000000         -89.900002         -19.200001          -2.500000
# 50%      191.000000         -82.199997         -16.500000           0.800000
# 75%      191.000000         -75.599998         -14.300000           4.000000
# max      501.000000         -62.099998          -9.800000          16.100000
#
#        Serving Cell Channel RSSI         CQI  Throughput DL  Throughput UL  \
# count                 539.000000  539.000000     539.000000     539.000000
# mean                  -47.763080    7.063080    5715.091748     433.390012
# std                     7.208916    1.082005    3843.695585     354.021400
# min                   -67.099998    4.000000       0.120000       0.700000
# 25%                   -53.049999    7.000000    2750.960083     185.415001
# 50%                   -47.299999    7.000000    5768.580078     350.260010
# 75%                   -42.000000    7.000000    8156.135009     619.959991
# max                   -26.600000   13.000000   26172.689450    1688.670044
#
#        Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# count      539.000000        539.000000         539.000000   539.000000
# mean         1.098330         30.039652          30.975457     0.363302
# std          0.298037          0.005977           0.009975     0.662248
# min          1.000000         29.975623          30.959722     0.030734
# 25%          1.000000         30.039874          30.969330     0.167032
# 50%          1.000000         30.040550          30.978168     0.253858
# 75%          1.000000         30.041362          30.978168     0.362078
# max          2.000000         30.046500          31.017482     8.612168
#
#        Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  \
# count                  539.000000              539.000000
# mean                   168.734694              -83.097217
# std                    138.798583                9.048749
# min                     12.000000             -102.400002
# 25%                     76.000000              -89.699997
# 50%                     77.000000              -83.199997
# 75%                    225.000000              -76.500000
# max                    502.000000              -59.799999
#
#        Neighbor Cell RSRQ: N1  latitude_Cell_N2  longitude_Cell_N2  \
# count              539.000000        539.000000         539.000000
# mean               -16.913173         30.038388          30.975286
# std                  3.694519          0.009197           0.009664
# min                -30.000000         29.975623          30.959722
# 25%                -18.400000         30.039874          30.969330
# 50%                -16.100000         30.040550          30.978168
# 75%                -14.500000         30.040635          30.978168
# max                 -9.400000         30.055470          31.021740
#
#        Distance_N2  Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  \
# count   539.000000                  539.000000              539.000000
# mean      0.515862                  187.946197              -86.815770
# std       1.115224                  141.003068                8.610599
# min       0.030734                   12.000000             -108.099998
# 25%       0.184135                   75.000000              -93.250000
# 50%       0.284347                  156.000000              -86.699997
# 75%       0.468675                  320.000000              -80.549999
# max       8.722353                  502.000000              -65.199997
#
#        Neighbor Cell RSRQ: N2  PDSCH BLER Carrier 1 (%)  \
# count              539.000000                539.000000
# mean               -20.694620                 15.749202
# std                  4.306383                  9.213560
# min                -30.000000                  0.000000
# 25%                -23.550000                 11.295000
# 50%                -20.000000                 14.100000
# 75%                -17.299999                 19.890000
# max                -11.100000                100.000000
#
#        MAC UL Throughput (kbps)  RLC Throughput DL (kbps)  \
# count                539.000000                539.000000
# mean                  95.584859               5643.477147
# std                   72.524371               5592.416732
# min                    0.000000                  0.000000
# 25%                   45.039999               1785.369995
# 50%                   86.180000               4557.649902
# 75%                  132.495003               7119.502785
# max                  415.220001              33996.589840
#
#        RLC Throughput UL (kbps)  PDCCH Downlink Grant Count Current  \
# count                539.000000                          539.000000
# mean                 102.569281                         1028.015833
# std                   97.713511                          581.465202
# min                    0.000000                            0.000000
# 25%                   33.350000                          695.000000
# 50%                   92.129997                         1107.000000
# 75%                  125.701727                         1431.500000
# max                  749.630005                         3679.000000
#
#        PDCCH Uplink Grant Count Current
# count                        539.000000
# mean                         520.762026
# std                          445.587307
# min                            0.000000
# 25%                          189.000000
# 50%                          411.000000
# 75%                          738.500000
# max                         2008.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Time                                539 non-null    object
#  1   Drive_Lat                           539 non-null    float64
#  2   Drive_Lon                           539 non-null    float64
#  3   Cell_lat                            539 non-null    float64
#  4   Cell_lon                            539 non-null    float64
#  5   Dis_Serving                         539 non-null    float64
#  6   Serving_Cell                        539 non-null    int64
#  7   Serving Cell RSRP                   539 non-null    float64
#  8   Serving Cell RSRQ                   539 non-null    float64
#  9   RS SINR Carrier 1                   539 non-null    float64
#  10  Serving Cell Channel RSSI           539 non-null    float64
#  11  CQI                                 539 non-null    int64
#  12  Throughput DL                       539 non-null    float64
#  13  Throughput UL                       539 non-null    float64
#  14  Rank Indicator                      539 non-null    int64
#  15  latitude_Cell_N1                    539 non-null    float64
#  16  longitude_Cell_N1                   539 non-null    float64
#  17  Distance_N1                         539 non-null    float64
#  18  Neighbor Cell Identity: N1          539 non-null    int64
#  19  Neighbor Cell RSRP: N1              539 non-null    float64
#  20  Neighbor Cell RSRQ: N1              539 non-null    float64
#  21  latitude_Cell_N2                    539 non-null    float64
#  22  longitude_Cell_N2                   539 non-null    float64
#  23  Distance_N2                         539 non-null    float64
#  24  Neighbor Cell Identity: N2          539 non-null    int64
#  25  Neighbor Cell RSRP: N2              539 non-null    float64
#  26  Neighbor Cell RSRQ: N2              539 non-null    float64
#  27  PDSCH BLER Carrier 1 (%)            539 non-null    float64
#  28  MAC UL Throughput (kbps)            539 non-null    float64
#  29  RLC Throughput DL (kbps)            539 non-null    float64
#  30  RLC Throughput UL (kbps)            539 non-null    float64
#  31  PDCCH Downlink Grant Count Current  539 non-null    float64
#  32  PDCCH Uplink Grant Count Current    539 non-null    float64
#  33  States                              539 non-null    object
# dtypes: float64(27), int64(5), object(2)
# memory usage: 143.3+ KB

# %% [markdown]
#  DATA VISUALIZATION

# %%
pre_df.columns
# Out:
# Index(['Time', 'Drive_Lat', 'Drive_Lon', 'Cell_lat', 'Cell_lon', 'Dis_Serving',
#        'Serving_Cell', 'Serving Cell RSRP', 'Serving Cell RSRQ',
#        'RS SINR Carrier 1', 'Serving Cell Channel RSSI', 'CQI',
#        'Throughput DL', 'Throughput UL', 'Rank Indicator', 'latitude_Cell_N1',
#        'longitude_Cell_N1', 'Distance_N1', 'Neighbor Cell Identity: N1',
#        'Neighbor Cell RSRP: N1', 'Neighbor Cell RSRQ: N1', 'latitude_Cell_N2',
#        'longitude_Cell_N2', 'Distance_N2', 'Neighbor Cell Identity: N2',
#        'Neighbor Cell RSRP: N2', 'Neighbor Cell RSRQ: N2',
#        'PDSCH BLER Carrier 1 (%)', 'MAC UL Throughput (kbps)',
#        'RLC Throughput DL (kbps)', 'RLC Throughput UL (kbps)',
#        'PDCCH Downlink Grant Count Current',
#        'PDCCH Uplink Grant Count Current', 'States'],
#       dtype='object')

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=pre_df['Throughput DL'])
# Out:
# <Axes: xlabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
dfplot = df
sns.scatterplot(data=dfplot,x='Serving Cell RSRP',y='Throughput DL')
# Out:
# <Axes: xlabel='Serving Cell RSRP', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='Serving Cell RSRQ',y='Throughput DL')
# Out:
# <Axes: xlabel='Serving Cell RSRQ', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='RS SINR Carrier 1',y='Throughput DL')
# Out:
# <Axes: xlabel='RS SINR Carrier 1', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='Throughput UL',y='Throughput DL')
# Out:
# <Axes: xlabel='Throughput UL', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='CQI',y='Throughput DL')
# Out:
# <Axes: xlabel='CQI', ylabel='Throughput DL'>

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(8, 5))
sn.boxplot(x=pre_df['Throughput DL'])
# Out:
# <Axes: xlabel='Throughput DL'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])
sns.displot(pre_df['Serving Cell RSRP'])
sns.displot(pre_df['Serving Cell RSRQ'])
sns.displot(pre_df['RS SINR Carrier 1'])
sns.displot(pre_df['Throughput UL'])

# %%
# pre_df.hist(bins=50, figsize=(20,15))
# sns.pairplot(pre_df)

# %%
pre_df.hist(bins=50, figsize=(20,15))
sns.distplot(kde=True,norm_hist=True,bins=50,rug=True)
# Out:
# <Axes: >

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 7
plt.rcParams["figure.figsize"] = fig_size

# %%
ax = sn.scatterplot(x=pre_df['Serving Cell Channel RSSI'], y=pre_df['RS SINR Carrier 1'], s=100,alpha=0.1, palette="icefire", hue=pre_df['Throughput DL'])
plt.title('DL-bitrate relationship between SINR and RSSI')
# Remove the legend and add a colorbar
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# Create a figure and axes for subplots (3 rows, 2 columns)
fig, axs = plt.subplots(2, 3, figsize=(12, 12))

# Scatter plot for Serving Cell RSRP
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Serving Cell RSRP'], ax=axs[0, 0])
axs[0, 0].set_title('Serving Cell RSRP (dBm)')

# Scatter plot for Serving Cell RSRQ
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Serving Cell RSRQ'], ax=axs[0, 1])
axs[0, 1].set_title('Serving Cell RSRQ (dB)')

# Scatter plot for Distance to Serving Cell
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Dis_Serving'], ax=axs[0, 2])
axs[1, 2].set_title('Distance to Serving Cell (m)')

# Scatter plot for Neighbor Cell RSRP: N1
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Neighbor Cell RSRP: N1'], ax=axs[1, 0])
axs[1, 0].set_title('Neighbor Cell RSRP: N1 (dBm)')

# Scatter plot for Neighbor Cell RSRQ: N1
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Neighbor Cell RSRQ: N1'], ax=axs[1, 1])
axs[1, 1].set_title('Neighbor Cell RSRQ: N1 (dB)')

fig.delaxes(axs[1, 2])


# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# Save the figure
fig.savefig("Overshooting.png")
