# %% [markdown]
# <a href="https://colab.research.google.com/github/Salahbendary/Performance-Analysis-and-Prediction-of-LTE-Networks-Using-AI/blob/main/NearestCell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nearest Cell [Good Case]

# %%
import pandas as pd
import numpy as np

# %%
nearestCell = pd.read_csv('/content/nearestCell.csv', encoding='ISO-8859-1')

# %%
nearestCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13541 entries, 0 to 13540
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 13541 non-null  int64
#  1   Time                                13467 non-null  object
#  2   Drive_Lat                           13541 non-null  float64
#  3   Drive_Lon                           13541 non-null  float64
#  4   Cell_lat                            13541 non-null  float64
#  5   Cell_lon                            13541 non-null  float64
#  6   Dis_Serving                         13541 non-null  float64
#  7   Serving_Cell                        13541 non-null  int64
#  8   Serving Cell RSRP                   13541 non-null  float64
#  9   Serving Cell RSRQ                   13541 non-null  float64
#  10  RS SINR Carrier 1                   13541 non-null  float64
#  11  Serving Cell Channel RSSI           13541 non-null  float64
#  12  CQI                                 13541 non-null  int64
#  13  Throughput DL                       13541 non-null  float64
#  14  Throughput UL                       13541 non-null  float64
#  15  Rank Indicator                      13541 non-null  int64
#  16  latitude_Cell_N1                    13541 non-null  float64
#  17  longitude_Cell_N1                   13541 non-null  float64
#  18  Distance_N1                         13541 non-null  float64
#  19  Neighbor Cell Identity: N1          13541 non-null  int64
#  20  Neighbor Cell RSRP: N1              13541 non-null  float64
#  21  Neighbor Cell RSRQ: N1              13541 non-null  float64
#  22  latitude_Cell_N2                    13467 non-null  float64
#  23  longitude_Cell_N2                   13467 non-null  float64
#  24  Distance_N2                         13467 non-null  float64
#  25  Neighbor Cell Identity: N2          13467 non-null  float64
#  26  Neighbor Cell RSRP: N2              13467 non-null  float64
#  27  Neighbor Cell RSRQ: N2              13467 non-null  float64
#  28  PDSCH BLER Carrier 1 (%)            13541 non-null  float64
#  29  MAC UL Throughput (kbps)            13541 non-null  float64
#  30  RLC Throughput DL (kbps)            13541 non-null  float64
#  31  RLC Throughput UL (kbps)            13541 non-null  float64
#  32  PDCCH Downlink Grant Count Current  13541 non-null  float64
#  33  PDCCH Uplink Grant Count Current    13541 non-null  float64
#  34  States                              13541 non-null  object
# dtypes: float64(28), int64(5), object(2)
# memory usage: 3.6+ MB

# %%
nearestCell.isna().sum()
# Out:
# ï»¿                                    0
# Time                                  74
# Drive_Lat                              0
# Drive_Lon                              0
# Cell_lat                               0
# Cell_lon                               0
# Dis_Serving                            0
# Serving_Cell                           0
# Serving Cell RSRP                      0
# Serving Cell RSRQ                      0
# RS SINR Carrier 1                      0
# Serving Cell Channel RSSI              0
# CQI                                    0
# Throughput DL                          0
# Throughput UL                          0
# Rank Indicator                         0
# latitude_Cell_N1                       0
# longitude_Cell_N1                      0
# Distance_N1                            0
# Neighbor Cell Identity: N1             0
# Neighbor Cell RSRP: N1                 0
# Neighbor Cell RSRQ: N1                 0
# latitude_Cell_N2                      74
# longitude_Cell_N2                     74
# Distance_N2                           74
# Neighbor Cell Identity: N2            74
# Neighbor Cell RSRP: N2                74
# Neighbor Cell RSRQ: N2                74
# PDSCH BLER Carrier 1 (%)               0
# MAC UL Throughput (kbps)               0
# RLC Throughput DL (kbps)               0
# RLC Throughput UL (kbps)               0
# PDCCH Downlink Grant Count Current     0
# PDCCH Uplink Grant Count Current       0
# States                                 0
# dtype: int64

# %%
nearestCell.head(2)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0    0  10:45:55 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 1    1  10:45:57 PM  30.038062  30.977077  30.04072  30.98725     1.022918
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  ...  \
# 0           285              -90.5              -13.5  ...
# 1           285              -91.0              -13.5  ...
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                       142.0              -95.300003                   -17.4
# 1                       142.0              -96.800003                   -19.9
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                       0.0                122.982238
# 1                       0.0                  4.100000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1               7119.502785                 24.000000
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           11.000000                         51.000000
#
#     States
# 0  Nearest
# 1  Nearest
#
# [2 rows x 35 columns]

# %%
nearestCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13541 entries, 0 to 13540
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 13541 non-null  int64
#  1   Time                                13467 non-null  object
#  2   Drive_Lat                           13541 non-null  float64
#  3   Drive_Lon                           13541 non-null  float64
#  4   Cell_lat                            13541 non-null  float64
#  5   Cell_lon                            13541 non-null  float64
#  6   Dis_Serving                         13541 non-null  float64
#  7   Serving_Cell                        13541 non-null  int64
#  8   Serving Cell RSRP                   13541 non-null  float64
#  9   Serving Cell RSRQ                   13541 non-null  float64
#  10  RS SINR Carrier 1                   13541 non-null  float64
#  11  Serving Cell Channel RSSI           13541 non-null  float64
#  12  CQI                                 13541 non-null  int64
#  13  Throughput DL                       13541 non-null  float64
#  14  Throughput UL                       13541 non-null  float64
#  15  Rank Indicator                      13541 non-null  int64
#  16  latitude_Cell_N1                    13541 non-null  float64
#  17  longitude_Cell_N1                   13541 non-null  float64
#  18  Distance_N1                         13541 non-null  float64
#  19  Neighbor Cell Identity: N1          13541 non-null  int64
#  20  Neighbor Cell RSRP: N1              13541 non-null  float64
#  21  Neighbor Cell RSRQ: N1              13541 non-null  float64
#  22  latitude_Cell_N2                    13467 non-null  float64
#  23  longitude_Cell_N2                   13467 non-null  float64
#  24  Distance_N2                         13467 non-null  float64
#  25  Neighbor Cell Identity: N2          13467 non-null  float64
#  26  Neighbor Cell RSRP: N2              13467 non-null  float64
#  27  Neighbor Cell RSRQ: N2              13467 non-null  float64
#  28  PDSCH BLER Carrier 1 (%)            13541 non-null  float64
#  29  MAC UL Throughput (kbps)            13541 non-null  float64
#  30  RLC Throughput DL (kbps)            13541 non-null  float64
#  31  RLC Throughput UL (kbps)            13541 non-null  float64
#  32  PDCCH Downlink Grant Count Current  13541 non-null  float64
#  33  PDCCH Uplink Grant Count Current    13541 non-null  float64
#  34  States                              13541 non-null  object
# dtypes: float64(28), int64(5), object(2)
# memory usage: 3.6+ MB

# %%
nearestCell.describe()
# Out:
#                 ï»¿     Drive_Lat     Drive_Lon      Cell_lat      Cell_lon  \
# count  13541.000000  13541.000000  13541.000000  13541.000000  13541.000000
# mean    7395.283288     30.037681     30.971731     30.037203     30.972484
# std     4274.555450      0.004061      0.009401      0.005735      0.008947
# min        0.000000     30.023643     30.955953     29.982552     30.939990
# 25%     3691.000000     30.035829     30.966324     30.034190     30.966194
# 50%     7379.000000     30.038451     30.970033     30.039874     30.971949
# 75%    11111.000000     30.040370     30.974781     30.040550     30.974717
# max    14826.000000     30.058490     31.049273     30.050030     31.029150
#
#         Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count  13541.000000  13541.000000       13541.000000       13541.000000
# mean       0.379703    163.491618         -80.163082         -14.602267
# std        0.500298    123.997960           9.702665           2.747988
# min        0.000576     12.000000        -109.099998         -30.000000
# 25%        0.171637     59.000000         -87.099998         -16.200001
# 50%        0.299284    156.000000         -80.000000         -14.200000
# 75%        0.420540    158.000000         -73.099998         -12.700000
# max        9.896567    502.000000         -52.400002          -5.900000
#
#        RS SINR Carrier 1  ...   Distance_N2  Neighbor Cell Identity: N2  \
# count       13541.000000  ...  13467.000000                13467.000000
# mean            4.938953  ...      0.911852                  195.863741
# std             5.761332  ...      1.102044                  146.655592
# min           -11.800000  ...      0.000576                    0.000000
# 25%             0.900000  ...      0.342176                   76.000000
# 50%             4.500000  ...      0.581724                  157.000000
# 75%             8.600000  ...      0.955835                  306.000000
# max            28.500000  ...      9.798236                  502.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count            13467.000000            13467.000000
# mean               -89.391223              -23.600007
# std                  7.952240                4.390730
# min               -115.900002              -30.000000
# 25%                -94.900002              -27.500000
# 50%                -89.300003              -23.500000
# 75%                -83.699997              -20.200001
# max                -65.599998               -9.800000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count              13541.000000              13541.000000
# mean                  15.391108                123.915104
# std                    8.327701                 81.094813
# min                    0.000000                  0.000000
# 25%                   10.900000                 71.629997
# 50%                   13.890000                119.900002
# 75%                   20.139999                164.199997
# max                  100.000000               1903.040039
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count              13541.000000              13541.000000
# mean                7159.020786                126.546765
# std                 6517.979011                101.083226
# min                    0.000000                  0.000000
# 25%                 3301.389893                 63.820000
# 50%                 6215.810059                116.489998
# 75%                 8725.059570                157.740005
# max               211894.046900               1746.780029
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                        13541.000000                      13541.000000
# mean                          1203.481440                        805.974285
# std                            582.370746                        517.034803
# min                              0.000000                          0.000000
# 25%                            847.000000                        427.000000
# 50%                           1264.000000                        733.000000
# 75%                           1680.000000                       1193.000000
# max                           5707.000000                       3399.000000
#
# [8 rows x 33 columns]

# %%
nearestCell.isna().sum()
# Out:
# ï»¿                                    0
# Time                                  74
# Drive_Lat                              0
# Drive_Lon                              0
# Cell_lat                               0
# Cell_lon                               0
# Dis_Serving                            0
# Serving_Cell                           0
# Serving Cell RSRP                      0
# Serving Cell RSRQ                      0
# RS SINR Carrier 1                      0
# Serving Cell Channel RSSI              0
# CQI                                    0
# Throughput DL                          0
# Throughput UL                          0
# Rank Indicator                         0
# latitude_Cell_N1                       0
# longitude_Cell_N1                      0
# Distance_N1                            0
# Neighbor Cell Identity: N1             0
# Neighbor Cell RSRP: N1                 0
# Neighbor Cell RSRQ: N1                 0
# latitude_Cell_N2                      74
# longitude_Cell_N2                     74
# Distance_N2                           74
# Neighbor Cell Identity: N2            74
# Neighbor Cell RSRP: N2                74
# Neighbor Cell RSRQ: N2                74
# PDSCH BLER Carrier 1 (%)               0
# MAC UL Throughput (kbps)               0
# RLC Throughput DL (kbps)               0
# RLC Throughput UL (kbps)               0
# PDCCH Downlink Grant Count Current     0
# PDCCH Uplink Grant Count Current       0
# States                                 0
# dtype: int64

# %%
FinalnearestCell = nearestCell.dropna(axis=0)

# %%
FinalnearestCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13467 entries, 0 to 13540
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 13467 non-null  int64
#  1   Time                                13467 non-null  object
#  2   Drive_Lat                           13467 non-null  float64
#  3   Drive_Lon                           13467 non-null  float64
#  4   Cell_lat                            13467 non-null  float64
#  5   Cell_lon                            13467 non-null  float64
#  6   Dis_Serving                         13467 non-null  float64
#  7   Serving_Cell                        13467 non-null  int64
#  8   Serving Cell RSRP                   13467 non-null  float64
#  9   Serving Cell RSRQ                   13467 non-null  float64
#  10  RS SINR Carrier 1                   13467 non-null  float64
#  11  Serving Cell Channel RSSI           13467 non-null  float64
#  12  CQI                                 13467 non-null  int64
#  13  Throughput DL                       13467 non-null  float64
#  14  Throughput UL                       13467 non-null  float64
#  15  Rank Indicator                      13467 non-null  int64
#  16  latitude_Cell_N1                    13467 non-null  float64
#  17  longitude_Cell_N1                   13467 non-null  float64
#  18  Distance_N1                         13467 non-null  float64
#  19  Neighbor Cell Identity: N1          13467 non-null  int64
#  20  Neighbor Cell RSRP: N1              13467 non-null  float64
#  21  Neighbor Cell RSRQ: N1              13467 non-null  float64
#  22  latitude_Cell_N2                    13467 non-null  float64
#  23  longitude_Cell_N2                   13467 non-null  float64
#  24  Distance_N2                         13467 non-null  float64
#  25  Neighbor Cell Identity: N2          13467 non-null  float64
#  26  Neighbor Cell RSRP: N2              13467 non-null  float64
#  27  Neighbor Cell RSRQ: N2              13467 non-null  float64
#  28  PDSCH BLER Carrier 1 (%)            13467 non-null  float64
#  29  MAC UL Throughput (kbps)            13467 non-null  float64
#  30  RLC Throughput DL (kbps)            13467 non-null  float64
#  31  RLC Throughput UL (kbps)            13467 non-null  float64
#  32  PDCCH Downlink Grant Count Current  13467 non-null  float64
#  33  PDCCH Uplink Grant Count Current    13467 non-null  float64
#  34  States                              13467 non-null  object
# dtypes: float64(28), int64(5), object(2)
# memory usage: 3.7+ MB

# %%
FinalnearestCell.describe()
# Out:
#                 ï»¿     Drive_Lat     Drive_Lon      Cell_lat      Cell_lon  \
# count  13467.000000  13467.000000  13467.000000  13467.000000  13467.000000
# mean    7389.014034     30.037679     30.971678     30.037202     30.972436
# std     4276.392405      0.004056      0.009274      0.005733      0.008838
# min        0.000000     30.023643     30.955953     29.982552     30.939990
# 25%     3684.500000     30.035830     30.966309     30.034190     30.966194
# 50%     7365.000000     30.038449     30.970006     30.039874     30.971949
# 75%    11111.500000     30.040371     30.974757     30.040550     30.974717
# max    14826.000000     30.058490     31.049273     30.050030     31.029150
#
#         Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count  13467.000000  13467.000000       13467.000000       13467.000000
# mean       0.379516    163.492389         -80.176468         -14.605963
# std        0.500514    124.123939           9.706999           2.749260
# min        0.000576     12.000000        -109.099998         -30.000000
# 25%        0.171306     59.000000         -87.099998         -16.200001
# 50%        0.299199    156.000000         -80.000000         -14.200000
# 75%        0.420452    158.000000         -73.099998         -12.700000
# max        9.896567    502.000000         -52.400002          -5.900000
#
#        RS SINR Carrier 1  ...   Distance_N2  Neighbor Cell Identity: N2  \
# count       13467.000000  ...  13467.000000                13467.000000
# mean            4.928526  ...      0.911852                  195.863741
# std             5.761173  ...      1.102044                  146.655592
# min           -11.800000  ...      0.000576                    0.000000
# 25%             0.900000  ...      0.342176                   76.000000
# 50%             4.500000  ...      0.581724                  157.000000
# 75%             8.600000  ...      0.955835                  306.000000
# max            28.500000  ...      9.798236                  502.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count            13467.000000            13467.000000
# mean               -89.391223              -23.600007
# std                  7.952240                4.390730
# min               -115.900002              -30.000000
# 25%                -94.900002              -27.500000
# 50%                -89.300003              -23.500000
# 75%                -83.699997              -20.200001
# max                -65.599998               -9.800000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count              13467.000000              13467.000000
# mean                  15.388055                123.870333
# std                    8.338432                 81.144541
# min                    0.000000                  0.000000
# 25%                   10.890000                 71.584999
# 50%                   13.880000                119.870003
# 75%                   20.145000                164.150002
# max                  100.000000               1903.040039
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count              13467.000000              13467.000000
# mean                7149.133829                126.432524
# std                 6511.347525                101.001372
# min                    0.000000                  0.000000
# 25%                 3294.750000                 63.539999
# 50%                 6208.029785                116.389999
# 75%                 8719.714843                157.659996
# max               211894.046900               1746.780029
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                        13467.000000                      13467.000000
# mean                          1203.590271                        806.482126
# std                            582.760780                        517.247656
# min                              0.000000                          0.000000
# 25%                            847.000000                        427.000000
# 50%                           1266.000000                        733.000000
# 75%                           1681.000000                       1193.000000
# max                           5707.000000                       3399.000000
#
# [8 rows x 33 columns]

# %%
FinalnearestCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
FinalnearestCell.head(5)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0    0  10:45:55 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 1    1  10:45:57 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 2    2  10:46:01 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 3    4  10:46:07 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 4    5  10:46:09 PM  30.038059  30.977072  30.04072  30.98725     1.023453
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  ...  \
# 0           285         -90.500000              -13.5  ...
# 1           285         -91.000000              -13.5  ...
# 2           285         -89.900002              -13.5  ...
# 3           285         -90.699997              -14.1  ...
# 4           285         -87.800003              -12.0  ...
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                       142.0              -95.300003              -17.400000
# 1                       142.0              -96.800003              -19.900000
# 2                        76.0              -92.400002              -15.500000
# 3                        13.0              -95.500000              -19.000000
# 4                        13.0              -94.800003              -18.299999
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                       0.0                122.982238
# 1                       0.0                  4.100000
# 2                       0.0                  0.840000
# 3                       0.0                  0.340000
# 4                       0.0                122.982238
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1               7119.502785                 24.000000
# 2                  0.020000                  0.410000
# 3                  0.040000                  0.190000
# 4               7119.502785                125.701727
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           11.000000                         51.000000
# 2                            4.000000                         51.000000
# 3                            2.000000                         28.000000
# 4                            1.000000                          2.000000
#
#     States
# 0  Nearest
# 1  Nearest
# 2  Nearest
# 3  Nearest
# 4  Nearest
#
# [5 rows x 35 columns]

# %%
FinalnearestCell.to_csv('FinalnearestCellFiltered.csv', index=True)

# %% [markdown]
# Preparation

# %%
# data mining libaries
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, GridSearchCV, learning_curve
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sn
import matplotlib.pyplot as plt

#plot libaries
import plotly
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True) # to show plots in notebook

# online plotly
#from plotly.plotly import plot, iplot
#plotly.tools.set_credentials_file(username='XXXXXXXXXXXXXXX', api_key='XXXXXXXXXXXXXXX')

# offline plotly
from plotly.offline import plot, iplot

# do not show any warnings
import warnings
warnings.filterwarnings('ignore')

SEED = 42 # specify seed for reproducable results
pd.set_option('display.max_columns', None) # prevents abbreviation (with '...') of columns in prints
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# DATASET ANALYSIS

# %%
# load the dataset
df = pd.read_csv('FinalnearestCellFiltered.csv')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# df = df.query('Throughput > 10000')
print("The dataset has %d rows and %d columns" % df.shape)
# Feature Selection
# df = df[['Serving Cell RSRP','Serving Cell Channel RSSI','Throughput UL','RLC Throughput DL (kbps)', 'MAC UL Throughput (kbps)', 'RS SINR Carrier 1', 'Serving Cell RSRQ','Throughput']]
# Out:
# The dataset has 13467 rows and 36 columns

# %%
# df = df [['Serving Cell RSRP','Serving Cell Channel RSSI','Throughput UL','RLC Throughput DL (kbps)', 'MAC UL Throughput (kbps)', 'RS SINR Carrier 1', 'Serving Cell RSRQ','Throughput','PDSCH BLER Carrier 1 (%)','PDCCH Downlink Grant Count Current','PDCCH Uplink Grant Count Current','RLC Throughput UL (kbps)']]

# %%
df = df.drop('Unnamed: 0',axis=True)

# %%
feature_selection = df[['Serving_Cell','Serving Cell RSRP','Serving Cell RSRQ','Serving Cell Channel RSSI','Throughput DL','Throughput UL']]
import seaborn as sns
# Correlation Score
plt.figure(figsize=(12, 10))
correlation_matrix = feature_selection.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, cmap='coolwarm', annot=True,linewidths=0.01, )
plt.title("Correlation Matrix", size=25)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.describe()
# Out:
#                 ï»¿     Drive_Lat     Drive_Lon      Cell_lat      Cell_lon  \
# count  13467.000000  13467.000000  13467.000000  13467.000000  13467.000000
# mean    7389.014034     30.037679     30.971678     30.037202     30.972436
# std     4276.392405      0.004056      0.009274      0.005733      0.008838
# min        0.000000     30.023643     30.955953     29.982552     30.939990
# 25%     3684.500000     30.035830     30.966309     30.034190     30.966194
# 50%     7365.000000     30.038449     30.970006     30.039874     30.971949
# 75%    11111.500000     30.040371     30.974757     30.040550     30.974717
# max    14826.000000     30.058490     31.049273     30.050030     31.029150
#
#         Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count  13467.000000  13467.000000       13467.000000       13467.000000
# mean       0.379516    163.492389         -80.176468         -14.605963
# std        0.500514    124.123939           9.706999           2.749260
# min        0.000576     12.000000        -109.099998         -30.000000
# 25%        0.171306     59.000000         -87.099998         -16.200001
# 50%        0.299199    156.000000         -80.000000         -14.200000
# 75%        0.420452    158.000000         -73.099998         -12.700000
# max        9.896567    502.000000         -52.400002          -5.900000
#
#        RS SINR Carrier 1  Serving Cell Channel RSSI           CQI  \
# count       13467.000000               13467.000000  13467.000000
# mean            4.928526                 -48.315928      7.470038
# std             5.761173                   7.809610      1.654348
# min           -11.800000                 -75.000000      4.000000
# 25%             0.900000                 -54.000000      7.000000
# 50%             4.500000                 -48.200001      7.000000
# 75%             8.600000                 -42.599998      8.000000
# max            28.500000                 -26.100000     15.000000
#
#        Throughput DL  Throughput UL  Rank Indicator  latitude_Cell_N1  \
# count   13467.000000   13467.000000    13467.000000      13467.000000
# mean     7144.091912     653.953879        1.257667         30.035235
# std      3831.700512     433.138363        0.437366          0.009911
# min         0.020000       0.000000        1.000000         29.958777
# 25%      4390.145019     317.420013        1.000000         30.034190
# 50%      7224.479980     575.359985        1.000000         30.039874
# 75%      9691.940430     949.845001        2.000000         30.040550
# max     35842.109380    1718.619995        2.000000         30.075200
#
#        longitude_Cell_N1   Distance_N1  Neighbor Cell Identity: N1  \
# count       13467.000000  13467.000000                13467.000000
# mean           30.972552      0.768362                  215.904136
# std             0.009375      1.017175                  159.711037
# min            30.921480      0.000576                    3.000000
# 25%            30.966194      0.269114                   76.000000
# 50%            30.971949      0.453845                  158.000000
# 75%            30.974717      0.770202                  308.000000
# max            31.039209     11.704588                  502.000000
#
#        Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  latitude_Cell_N2  \
# count            13467.000000            13467.000000      13467.000000
# mean               -85.053991              -19.229866         30.035162
# std                  8.920858                4.406013          0.010982
# min               -112.599998              -30.000000         29.958777
# 25%                -91.400002              -21.799999         30.033771
# 50%                -85.000000              -18.600000         30.039874
# 75%                -78.699997              -16.000000         30.040550
# max                -55.700001               -5.300000         30.075200
#
#        longitude_Cell_N2   Distance_N2  Neighbor Cell Identity: N2  \
# count       13467.000000  13467.000000                13467.000000
# mean           30.972061      0.911852                  195.863741
# std             0.009827      1.102044                  146.655592
# min            30.907840      0.000576                    0.000000
# 25%            30.966194      0.342176                   76.000000
# 50%            30.971611      0.581724                  157.000000
# 75%            30.974717      0.955835                  306.000000
# max            31.032543      9.798236                  502.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count            13467.000000            13467.000000
# mean               -89.391223              -23.600007
# std                  7.952240                4.390730
# min               -115.900002              -30.000000
# 25%                -94.900002              -27.500000
# 50%                -89.300003              -23.500000
# 75%                -83.699997              -20.200001
# max                -65.599998               -9.800000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count              13467.000000              13467.000000
# mean                  15.388055                123.870333
# std                    8.338432                 81.144541
# min                    0.000000                  0.000000
# 25%                   10.890000                 71.584999
# 50%                   13.880000                119.870003
# 75%                   20.145000                164.150002
# max                  100.000000               1903.040039
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count              13467.000000              13467.000000
# mean                7149.133829                126.432524
# std                 6511.347525                101.001372
# min                    0.000000                  0.000000
# 25%                 3294.750000                 63.539999
# 50%                 6208.029785                116.389999
# 75%                 8719.714843                157.659996
# max               211894.046900               1746.780029
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                        13467.000000                      13467.000000
# mean                          1203.590271                        806.482126
# std                            582.760780                        517.247656
# min                              0.000000                          0.000000
# 25%                            847.000000                        427.000000
# 50%                           1266.000000                        733.000000
# 75%                           1681.000000                       1193.000000
# max                           5707.000000                       3399.000000

# %%
df.columns
# Out:
# Index(['ï»¿', 'Time', 'Drive_Lat', 'Drive_Lon', 'Cell_lat', 'Cell_lon',
#        'Dis_Serving', 'Serving_Cell', 'Serving Cell RSRP', 'Serving Cell RSRQ',
#        'RS SINR Carrier 1', 'Serving Cell Channel RSSI', 'CQI',
#        'Throughput DL', 'Throughput UL', 'Rank Indicator', 'latitude_Cell_N1',
#        'longitude_Cell_N1', 'Distance_N1', 'Neighbor Cell Identity: N1',
#        'Neighbor Cell RSRP: N1', 'Neighbor Cell RSRQ: N1', 'latitude_Cell_N2',
#        'longitude_Cell_N2', 'Distance_N2', 'Neighbor Cell Identity: N2',
#        'Neighbor Cell RSRP: N2', 'Neighbor Cell RSRQ: N2',
#        'PDSCH BLER Carrier 1 (%)', 'MAC UL Throughput (kbps)',
#        'RLC Throughput DL (kbps)', 'RLC Throughput UL (kbps)',
#        'PDCCH Downlink Grant Count Current',
#        'PDCCH Uplink Grant Count Current', 'States'],
#       dtype='object')

# %%
count_nan = df.isna().sum().sum()
print ('Count of NaN/NULL values: ' + str(count_nan))
# Out:
# Count of NaN/NULL values: 0

# %%
df = df.dropna()

# %%
df.head(3)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0    0  10:45:55 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 1    1  10:45:57 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 2    2  10:46:01 PM  30.038062  30.977077  30.04072  30.98725     1.022918
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           285         -90.500000              -13.5                0.5
# 1           285         -91.000000              -13.5               -0.8
# 2           285         -89.900002              -13.5               -1.0
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -56.900002    7           0.49     638.419165
# 1                 -57.299999    7          11.81     638.419165
# 2                 -56.099998    7           0.37      28.730000
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1          30.04055          30.978168     0.295961
# 1               1          30.04055          30.978168     0.295961
# 2               1          30.04072          30.987250     1.022918
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                          76              -91.800003                   -13.5
# 1                          76              -92.900002                   -15.7
# 2                         305              -91.500000                   -17.9
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0          30.04650          30.969400     1.194330
# 1          30.04650          30.969400     1.194330
# 2          30.04055          30.978168     0.295961
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                       142.0              -95.300003                   -17.4
# 1                       142.0              -96.800003                   -19.9
# 2                        76.0              -92.400002                   -15.5
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                       0.0                122.982238
# 1                       0.0                  4.100000
# 2                       0.0                  0.840000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1               7119.502785                 24.000000
# 2                  0.020000                  0.410000
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           11.000000                         51.000000
# 2                            4.000000                         51.000000
#
#     States
# 0  Nearest
# 1  Nearest
# 2  Nearest

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13467 entries, 0 to 13466
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 13467 non-null  int64
#  1   Time                                13467 non-null  object
#  2   Drive_Lat                           13467 non-null  float64
#  3   Drive_Lon                           13467 non-null  float64
#  4   Cell_lat                            13467 non-null  float64
#  5   Cell_lon                            13467 non-null  float64
#  6   Dis_Serving                         13467 non-null  float64
#  7   Serving_Cell                        13467 non-null  int64
#  8   Serving Cell RSRP                   13467 non-null  float64
#  9   Serving Cell RSRQ                   13467 non-null  float64
#  10  RS SINR Carrier 1                   13467 non-null  float64
#  11  Serving Cell Channel RSSI           13467 non-null  float64
#  12  CQI                                 13467 non-null  int64
#  13  Throughput DL                       13467 non-null  float64
#  14  Throughput UL                       13467 non-null  float64
#  15  Rank Indicator                      13467 non-null  int64
#  16  latitude_Cell_N1                    13467 non-null  float64
#  17  longitude_Cell_N1                   13467 non-null  float64
#  18  Distance_N1                         13467 non-null  float64
#  19  Neighbor Cell Identity: N1          13467 non-null  int64
#  20  Neighbor Cell RSRP: N1              13467 non-null  float64
#  21  Neighbor Cell RSRQ: N1              13467 non-null  float64
#  22  latitude_Cell_N2                    13467 non-null  float64
#  23  longitude_Cell_N2                   13467 non-null  float64
#  24  Distance_N2                         13467 non-null  float64
#  25  Neighbor Cell Identity: N2          13467 non-null  float64
#  26  Neighbor Cell RSRP: N2              13467 non-null  float64
#  27  Neighbor Cell RSRQ: N2              13467 non-null  float64
#  28  PDSCH BLER Carrier 1 (%)            13467 non-null  float64
#  29  MAC UL Throughput (kbps)            13467 non-null  float64
#  30  RLC Throughput DL (kbps)            13467 non-null  float64
#  31  RLC Throughput UL (kbps)            13467 non-null  float64
#  32  PDCCH Downlink Grant Count Current  13467 non-null  float64
#  33  PDCCH Uplink Grant Count Current    13467 non-null  float64
#  34  States                              13467 non-null  object
# dtypes: float64(28), int64(5), object(2)
# memory usage: 3.6+ MB

# %%
df.drop(['ï»¿'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13467 entries, 0 to 13466
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Time                                13467 non-null  object
#  1   Drive_Lat                           13467 non-null  float64
#  2   Drive_Lon                           13467 non-null  float64
#  3   Cell_lat                            13467 non-null  float64
#  4   Cell_lon                            13467 non-null  float64
#  5   Dis_Serving                         13467 non-null  float64
#  6   Serving_Cell                        13467 non-null  int64
#  7   Serving Cell RSRP                   13467 non-null  float64
#  8   Serving Cell RSRQ                   13467 non-null  float64
#  9   RS SINR Carrier 1                   13467 non-null  float64
#  10  Serving Cell Channel RSSI           13467 non-null  float64
#  11  CQI                                 13467 non-null  int64
#  12  Throughput DL                       13467 non-null  float64
#  13  Throughput UL                       13467 non-null  float64
#  14  Rank Indicator                      13467 non-null  int64
#  15  latitude_Cell_N1                    13467 non-null  float64
#  16  longitude_Cell_N1                   13467 non-null  float64
#  17  Distance_N1                         13467 non-null  float64
#  18  Neighbor Cell Identity: N1          13467 non-null  int64
#  19  Neighbor Cell RSRP: N1              13467 non-null  float64
#  20  Neighbor Cell RSRQ: N1              13467 non-null  float64
#  21  latitude_Cell_N2                    13467 non-null  float64
#  22  longitude_Cell_N2                   13467 non-null  float64
#  23  Distance_N2                         13467 non-null  float64
#  24  Neighbor Cell Identity: N2          13467 non-null  float64
#  25  Neighbor Cell RSRP: N2              13467 non-null  float64
#  26  Neighbor Cell RSRQ: N2              13467 non-null  float64
#  27  PDSCH BLER Carrier 1 (%)            13467 non-null  float64
#  28  MAC UL Throughput (kbps)            13467 non-null  float64
#  29  RLC Throughput DL (kbps)            13467 non-null  float64
#  30  RLC Throughput UL (kbps)            13467 non-null  float64
#  31  PDCCH Downlink Grant Count Current  13467 non-null  float64
#  32  PDCCH Uplink Grant Count Current    13467 non-null  float64
#  33  States                              13467 non-null  object
# dtypes: float64(28), int64(4), object(2)
# memory usage: 3.5+ MB

# %%
def preprocess_data(df):
    pre_df = df.copy()
    return pre_df

# %%
pre_df = preprocess_data(df)
pre_df.head(3)
# Out:
#           Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0  10:45:55 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 1  10:45:57 PM  30.038062  30.977077  30.04072  30.98725     1.022918
# 2  10:46:01 PM  30.038062  30.977077  30.04072  30.98725     1.022918
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           285         -90.500000              -13.5                0.5
# 1           285         -91.000000              -13.5               -0.8
# 2           285         -89.900002              -13.5               -1.0
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -56.900002    7           0.49     638.419165
# 1                 -57.299999    7          11.81     638.419165
# 2                 -56.099998    7           0.37      28.730000
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1          30.04055          30.978168     0.295961
# 1               1          30.04055          30.978168     0.295961
# 2               1          30.04072          30.987250     1.022918
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                          76              -91.800003                   -13.5
# 1                          76              -92.900002                   -15.7
# 2                         305              -91.500000                   -17.9
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0          30.04650          30.969400     1.194330
# 1          30.04650          30.969400     1.194330
# 2          30.04055          30.978168     0.295961
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                       142.0              -95.300003                   -17.4
# 1                       142.0              -96.800003                   -19.9
# 2                        76.0              -92.400002                   -15.5
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                       0.0                122.982238
# 1                       0.0                  4.100000
# 2                       0.0                  0.840000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               7119.502785                125.701727
# 1               7119.502785                 24.000000
# 2                  0.020000                  0.410000
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                         1186.506835                        784.946444
# 1                           11.000000                         51.000000
# 2                            4.000000                         51.000000
#
#     States
# 0  Nearest
# 1  Nearest
# 2  Nearest

# %%
print("The dataset has %d rows and %d columns." % pre_df.shape)
# Out:
# The dataset has 13467 rows and 34 columns.

# %%
pre_df.describe()
# Out:
#           Drive_Lat     Drive_Lon      Cell_lat      Cell_lon   Dis_Serving  \
# count  13467.000000  13467.000000  13467.000000  13467.000000  13467.000000
# mean      30.037679     30.971678     30.037202     30.972436      0.379516
# std        0.004056      0.009274      0.005733      0.008838      0.500514
# min       30.023643     30.955953     29.982552     30.939990      0.000576
# 25%       30.035830     30.966309     30.034190     30.966194      0.171306
# 50%       30.038449     30.970006     30.039874     30.971949      0.299199
# 75%       30.040371     30.974757     30.040550     30.974717      0.420452
# max       30.058490     31.049273     30.050030     31.029150      9.896567
#
#        Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# count  13467.000000       13467.000000       13467.000000       13467.000000
# mean     163.492389         -80.176468         -14.605963           4.928526
# std      124.123939           9.706999           2.749260           5.761173
# min       12.000000        -109.099998         -30.000000         -11.800000
# 25%       59.000000         -87.099998         -16.200001           0.900000
# 50%      156.000000         -80.000000         -14.200000           4.500000
# 75%      158.000000         -73.099998         -12.700000           8.600000
# max      502.000000         -52.400002          -5.900000          28.500000
#
#        Serving Cell Channel RSSI           CQI  Throughput DL  Throughput UL  \
# count               13467.000000  13467.000000   13467.000000   13467.000000
# mean                  -48.315928      7.470038    7144.091912     653.953879
# std                     7.809610      1.654348    3831.700512     433.138363
# min                   -75.000000      4.000000       0.020000       0.000000
# 25%                   -54.000000      7.000000    4390.145019     317.420013
# 50%                   -48.200001      7.000000    7224.479980     575.359985
# 75%                   -42.599998      8.000000    9691.940430     949.845001
# max                   -26.100000     15.000000   35842.109380    1718.619995
#
#        Rank Indicator  latitude_Cell_N1  longitude_Cell_N1   Distance_N1  \
# count    13467.000000      13467.000000       13467.000000  13467.000000
# mean         1.257667         30.035235          30.972552      0.768362
# std          0.437366          0.009911           0.009375      1.017175
# min          1.000000         29.958777          30.921480      0.000576
# 25%          1.000000         30.034190          30.966194      0.269114
# 50%          1.000000         30.039874          30.971949      0.453845
# 75%          2.000000         30.040550          30.974717      0.770202
# max          2.000000         30.075200          31.039209     11.704588
#
#        Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  \
# count                13467.000000            13467.000000
# mean                   215.904136              -85.053991
# std                    159.711037                8.920858
# min                      3.000000             -112.599998
# 25%                     76.000000              -91.400002
# 50%                    158.000000              -85.000000
# 75%                    308.000000              -78.699997
# max                    502.000000              -55.700001
#
#        Neighbor Cell RSRQ: N1  latitude_Cell_N2  longitude_Cell_N2  \
# count            13467.000000      13467.000000       13467.000000
# mean               -19.229866         30.035162          30.972061
# std                  4.406013          0.010982           0.009827
# min                -30.000000         29.958777          30.907840
# 25%                -21.799999         30.033771          30.966194
# 50%                -18.600000         30.039874          30.971611
# 75%                -16.000000         30.040550          30.974717
# max                 -5.300000         30.075200          31.032543
#
#         Distance_N2  Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  \
# count  13467.000000                13467.000000            13467.000000
# mean       0.911852                  195.863741              -89.391223
# std        1.102044                  146.655592                7.952240
# min        0.000576                    0.000000             -115.900002
# 25%        0.342176                   76.000000              -94.900002
# 50%        0.581724                  157.000000              -89.300003
# 75%        0.955835                  306.000000              -83.699997
# max        9.798236                  502.000000              -65.599998
#
#        Neighbor Cell RSRQ: N2  PDSCH BLER Carrier 1 (%)  \
# count            13467.000000              13467.000000
# mean               -23.600007                 15.388055
# std                  4.390730                  8.338432
# min                -30.000000                  0.000000
# 25%                -27.500000                 10.890000
# 50%                -23.500000                 13.880000
# 75%                -20.200001                 20.145000
# max                 -9.800000                100.000000
#
#        MAC UL Throughput (kbps)  RLC Throughput DL (kbps)  \
# count              13467.000000              13467.000000
# mean                 123.870333               7149.133829
# std                   81.144541               6511.347525
# min                    0.000000                  0.000000
# 25%                   71.584999               3294.750000
# 50%                  119.870003               6208.029785
# 75%                  164.150002               8719.714843
# max                 1903.040039             211894.046900
#
#        RLC Throughput UL (kbps)  PDCCH Downlink Grant Count Current  \
# count              13467.000000                        13467.000000
# mean                 126.432524                         1203.590271
# std                  101.001372                          582.760780
# min                    0.000000                            0.000000
# 25%                   63.539999                          847.000000
# 50%                  116.389999                         1266.000000
# 75%                  157.659996                         1681.000000
# max                 1746.780029                         5707.000000
#
#        PDCCH Uplink Grant Count Current
# count                      13467.000000
# mean                         806.482126
# std                          517.247656
# min                            0.000000
# 25%                          427.000000
# 50%                          733.000000
# 75%                         1193.000000
# max                         3399.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13467 entries, 0 to 13466
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Time                                13467 non-null  object
#  1   Drive_Lat                           13467 non-null  float64
#  2   Drive_Lon                           13467 non-null  float64
#  3   Cell_lat                            13467 non-null  float64
#  4   Cell_lon                            13467 non-null  float64
#  5   Dis_Serving                         13467 non-null  float64
#  6   Serving_Cell                        13467 non-null  int64
#  7   Serving Cell RSRP                   13467 non-null  float64
#  8   Serving Cell RSRQ                   13467 non-null  float64
#  9   RS SINR Carrier 1                   13467 non-null  float64
#  10  Serving Cell Channel RSSI           13467 non-null  float64
#  11  CQI                                 13467 non-null  int64
#  12  Throughput DL                       13467 non-null  float64
#  13  Throughput UL                       13467 non-null  float64
#  14  Rank Indicator                      13467 non-null  int64
#  15  latitude_Cell_N1                    13467 non-null  float64
#  16  longitude_Cell_N1                   13467 non-null  float64
#  17  Distance_N1                         13467 non-null  float64
#  18  Neighbor Cell Identity: N1          13467 non-null  int64
#  19  Neighbor Cell RSRP: N1              13467 non-null  float64
#  20  Neighbor Cell RSRQ: N1              13467 non-null  float64
#  21  latitude_Cell_N2                    13467 non-null  float64
#  22  longitude_Cell_N2                   13467 non-null  float64
#  23  Distance_N2                         13467 non-null  float64
#  24  Neighbor Cell Identity: N2          13467 non-null  float64
#  25  Neighbor Cell RSRP: N2              13467 non-null  float64
#  26  Neighbor Cell RSRQ: N2              13467 non-null  float64
#  27  PDSCH BLER Carrier 1 (%)            13467 non-null  float64
#  28  MAC UL Throughput (kbps)            13467 non-null  float64
#  29  RLC Throughput DL (kbps)            13467 non-null  float64
#  30  RLC Throughput UL (kbps)            13467 non-null  float64
#  31  PDCCH Downlink Grant Count Current  13467 non-null  float64
#  32  PDCCH Uplink Grant Count Current    13467 non-null  float64
#  33  States                              13467 non-null  object
# dtypes: float64(28), int64(4), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
#  DATA VISUALIZATION

# %%
pre_df.columns
# Out:
# Index(['Time', 'Drive_Lat', 'Drive_Lon', 'Cell_lat', 'Cell_lon', 'Dis_Serving',
#        'Serving_Cell', 'Serving Cell RSRP', 'Serving Cell RSRQ',
#        'RS SINR Carrier 1', 'Serving Cell Channel RSSI', 'CQI',
#        'Throughput DL', 'Throughput UL', 'Rank Indicator', 'latitude_Cell_N1',
#        'longitude_Cell_N1', 'Distance_N1', 'Neighbor Cell Identity: N1',
#        'Neighbor Cell RSRP: N1', 'Neighbor Cell RSRQ: N1', 'latitude_Cell_N2',
#        'longitude_Cell_N2', 'Distance_N2', 'Neighbor Cell Identity: N2',
#        'Neighbor Cell RSRP: N2', 'Neighbor Cell RSRQ: N2',
#        'PDSCH BLER Carrier 1 (%)', 'MAC UL Throughput (kbps)',
#        'RLC Throughput DL (kbps)', 'RLC Throughput UL (kbps)',
#        'PDCCH Downlink Grant Count Current',
#        'PDCCH Uplink Grant Count Current', 'States'],
#       dtype='object')

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=pre_df['Throughput DL'])
# Out:
# <Axes: xlabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
dfplot = df
sns.scatterplot(data=dfplot,x='Serving Cell RSRP',y='Throughput DL')
# Out:
# <Axes: xlabel='Serving Cell RSRP', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='Serving Cell RSRQ',y='Throughput DL')
# Out:
# <Axes: xlabel='Serving Cell RSRQ', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='RS SINR Carrier 1',y='Throughput DL')
# Out:
# <Axes: xlabel='RS SINR Carrier 1', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='Throughput UL',y='Throughput DL')
# Out:
# <Axes: xlabel='Throughput UL', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='CQI',y='Throughput DL')
# Out:
# <Axes: xlabel='CQI', ylabel='Throughput DL'>

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(8, 5))
sn.boxplot(x=pre_df['Throughput DL'])
# Out:
# <Axes: xlabel='Throughput DL'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])
sns.displot(pre_df['Serving Cell RSRP'])
sns.displot(pre_df['Serving Cell RSRQ'])
sns.displot(pre_df['RS SINR Carrier 1'])
sns.displot(pre_df['Throughput UL'])

# %%
# pre_df.hist(bins=50, figsize=(20,15))
# sns.pairplot(pre_df)

# %%
pre_df.hist(bins=50, figsize=(20,15))
sns.distplot(kde=True,norm_hist=True,bins=50,rug=True)
# Out:
# <Axes: >

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 7
plt.rcParams["figure.figsize"] = fig_size

# %%
ax = sn.scatterplot(x=pre_df['Serving Cell Channel RSSI'], y=pre_df['RS SINR Carrier 1'], s=100,alpha=0.1, palette="icefire", hue=pre_df['Throughput DL'])
plt.title('DL-bitrate relationship between SINR and RSSI')
# Remove the legend and add a colorbar
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# Create a figure and axes for subplots (4 rows, 2 columns)
fig, axs = plt.subplots(3,3, figsize=(15, 20))

# Scatter plot for Serving Cell RSRP
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Serving Cell RSRP'], ax=axs[0, 0])
axs[0, 0].set_title('Serving Cell RSRP (dBm)')

# Scatter plot for Serving Cell RSRQ
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Serving Cell RSRQ'], ax=axs[0, 1])
axs[0, 1].set_title('Serving Cell RSRQ (dB)')

# Scatter plot for RS SINR Carrier 1
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['RS SINR Carrier 1'], ax=axs[0, 2])
axs[0, 2].set_title('RS SINR Carrier 1 (dB)')

# Scatter plot for Serving Cell Channel RSSI
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Serving Cell Channel RSSI'], ax=axs[1,0])
axs[1, 0].set_title('Serving Cell Channel RSSI (dBm)')

# Scatter plot for CQI
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['CQI'], ax=axs[1, 1])
axs[1, 1].set_title('CQI')

# Scatter plot for Throughput DL
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Throughput DL'], ax=axs[1, 2])
axs[1, 2].set_title('Throughput DL (Mbps)')

# Scatter plot for Throughput UL
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Throughput UL'], ax=axs[2, 0])
axs[2, 0].set_title('Throughput UL (Mbps)')

fig.delaxes(axs[2, 1])
fig.delaxes(axs[2, 2])


# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()


# Save the figure
fig.savefig("nearestCell.png")
