# %% [markdown]
# <a href="https://colab.research.google.com/github/Salahbendary/Performance-Analysis-and-Prediction-of-LTE-Networks-Using-AI/blob/main/LoadedCell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loaded Cell Problem

# %%
import pandas as pd
import numpy as np

# %%
LoadedCell = pd.read_csv('/content/LoadedCell.csv', encoding='ISO-8859-1')

# %%
LoadedCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 128 non-null    int64
#  1   Time                                128 non-null    object
#  2   Drive_Lat                           128 non-null    float64
#  3   Drive_Lon                           128 non-null    float64
#  4   Cell_lat                            128 non-null    float64
#  5   Cell_lon                            128 non-null    float64
#  6   Dis_Serving                         128 non-null    float64
#  7   Serving_Cell                        128 non-null    int64
#  8   Serving Cell RSRP                   128 non-null    float64
#  9   Serving Cell RSRQ                   128 non-null    float64
#  10  RS SINR Carrier 1                   128 non-null    float64
#  11  Serving Cell Channel RSSI           128 non-null    float64
#  12  CQI                                 128 non-null    int64
#  13  Throughput DL                       128 non-null    float64
#  14  Throughput UL                       128 non-null    float64
#  15  Rank Indicator                      128 non-null    int64
#  16  latitude_Cell_N1                    128 non-null    float64
#  17  longitude_Cell_N1                   128 non-null    float64
#  18  Distance_N1                         128 non-null    float64
#  19  Neighbor Cell Identity: N1          128 non-null    int64
#  20  Neighbor Cell RSRP: N1              128 non-null    float64
#  21  Neighbor Cell RSRQ: N1              128 non-null    float64
#  22  latitude_Cell_N2                    128 non-null    float64
#  23  longitude_Cell_N2                   128 non-null    float64
#  24  Distance_N2                         128 non-null    float64
#  25  Neighbor Cell Identity: N2          128 non-null    int64
#  26  Neighbor Cell RSRP: N2              128 non-null    float64
#  27  Neighbor Cell RSRQ: N2              128 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            128 non-null    float64
#  29  MAC UL Throughput (kbps)            128 non-null    float64
#  30  RLC Throughput DL (kbps)            128 non-null    float64
#  31  RLC Throughput UL (kbps)            128 non-null    float64
#  32  PDCCH Downlink Grant Count Current  128 non-null    int64
#  33  PDCCH Uplink Grant Count Current    128 non-null    int64
#  34  States                              128 non-null    object
# dtypes: float64(25), int64(8), object(2)
# memory usage: 35.1+ KB

# %%
LoadedCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
LoadedCell.head(2)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0  615  11:12:29 PM  30.041205  30.967895   30.0465   30.9694     0.606278
# 1  616  11:12:31 PM  30.041176  30.967834   30.0465   30.9694     0.610925
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  ...  \
# 0           143         -92.699997              -13.8  ...
# 1           143         -92.900002              -13.5  ...
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                          33             -100.699997              -24.900000
# 1                          15             -102.599998              -21.700001
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                 23.389999                 65.860001
# 1                 22.610001                 46.130001
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               6201.459961                     93.32
# 1               3518.719971                     46.75
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                                1123                               230
# 1                                1142                               270
#
#    States
# 0  Loaded
# 1  Loaded
#
# [2 rows x 35 columns]

# %%
LoadedCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 128 non-null    int64
#  1   Time                                128 non-null    object
#  2   Drive_Lat                           128 non-null    float64
#  3   Drive_Lon                           128 non-null    float64
#  4   Cell_lat                            128 non-null    float64
#  5   Cell_lon                            128 non-null    float64
#  6   Dis_Serving                         128 non-null    float64
#  7   Serving_Cell                        128 non-null    int64
#  8   Serving Cell RSRP                   128 non-null    float64
#  9   Serving Cell RSRQ                   128 non-null    float64
#  10  RS SINR Carrier 1                   128 non-null    float64
#  11  Serving Cell Channel RSSI           128 non-null    float64
#  12  CQI                                 128 non-null    int64
#  13  Throughput DL                       128 non-null    float64
#  14  Throughput UL                       128 non-null    float64
#  15  Rank Indicator                      128 non-null    int64
#  16  latitude_Cell_N1                    128 non-null    float64
#  17  longitude_Cell_N1                   128 non-null    float64
#  18  Distance_N1                         128 non-null    float64
#  19  Neighbor Cell Identity: N1          128 non-null    int64
#  20  Neighbor Cell RSRP: N1              128 non-null    float64
#  21  Neighbor Cell RSRQ: N1              128 non-null    float64
#  22  latitude_Cell_N2                    128 non-null    float64
#  23  longitude_Cell_N2                   128 non-null    float64
#  24  Distance_N2                         128 non-null    float64
#  25  Neighbor Cell Identity: N2          128 non-null    int64
#  26  Neighbor Cell RSRP: N2              128 non-null    float64
#  27  Neighbor Cell RSRQ: N2              128 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            128 non-null    float64
#  29  MAC UL Throughput (kbps)            128 non-null    float64
#  30  RLC Throughput DL (kbps)            128 non-null    float64
#  31  RLC Throughput UL (kbps)            128 non-null    float64
#  32  PDCCH Downlink Grant Count Current  128 non-null    int64
#  33  PDCCH Uplink Grant Count Current    128 non-null    int64
#  34  States                              128 non-null    object
# dtypes: float64(25), int64(8), object(2)
# memory usage: 35.1+ KB

# %%
LoadedCell.describe()
# Out:
#                 ï»¿   Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  \
# count    128.000000  128.000000  128.000000  128.000000  128.000000
# mean    8385.578125   30.039614   30.969675   30.040927   30.971013
# std     4232.608450    0.004206    0.008248    0.008437    0.009181
# min      615.000000   30.030208   30.956015   30.008730   30.959722
# 25%     5586.750000   30.038012   30.963149   30.034190   30.963140
# 50%     8636.500000   30.039316   30.967864   30.040720   30.969330
# 75%    12639.250000   30.043566   30.974809   30.050030   30.978168
# max    14807.000000   30.044623   31.014428   30.050030   31.008840
#
#        Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count   128.000000    128.000000         128.000000         128.000000
# mean      0.683282    144.757812         -79.851563         -13.818750
# std       0.520606     99.307345           8.839835           2.229359
# min       0.338531     14.000000        -100.000000         -18.200001
# 25%       0.442779     76.000000         -86.724998         -15.200000
# 50%       0.629892    145.000000         -80.399998         -14.100000
# 75%       0.718876    148.250000         -74.975000         -12.775000
# max       3.797824    421.000000         -58.200001          -7.400000
#
#        RS SINR Carrier 1  ...  Distance_N2  Neighbor Cell Identity: N2  \
# count         128.000000  ...   128.000000                  128.000000
# mean            5.753906  ...     1.690062                  170.882812
# std             3.988722  ...     1.726977                  143.436431
# min            -3.200000  ...     0.225680                    3.000000
# 25%             2.875000  ...     0.435444                   59.750000
# 50%             5.850000  ...     1.023931                  152.000000
# 75%             8.625000  ...     3.299135                  191.000000
# max            16.400000  ...     8.289444                  501.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count              128.000000              128.000000
# mean               -90.822656              -25.360937
# std                  8.320492                3.853156
# min               -111.300003              -30.000000
# 25%                -96.525000              -28.925000
# 50%                -91.199997              -25.900000
# 75%                -86.400002              -22.775000
# max                -71.500000              -15.200000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count                128.000000                128.000000
# mean                  14.100547                126.784922
# std                    8.655461                 69.268965
# min                    0.000000                  0.000000
# 25%                   10.345000                 72.820002
# 50%                   12.920000                134.845001
# 75%                   17.892499                169.684994
# max                   54.310001                307.660004
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count                128.000000                128.000000
# mean                7651.207852                136.374378
# std                 6305.801870                102.210063
# min                    0.000000                  0.000000
# 25%                 3880.547486                 67.282499
# 50%                 6235.935059                125.695864
# 75%                 9668.969726                171.692505
# max                36643.968750                708.979981
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                          128.000000                        128.000000
# mean                          1227.195312                        837.203125
# std                            563.587735                        527.272933
# min                              0.000000                          2.000000
# 25%                            943.750000                        417.750000
# 50%                           1287.000000                        833.500000
# 75%                           1666.500000                       1293.750000
# max                           2007.000000                       1933.000000
#
# [8 rows x 33 columns]

# %%
LoadedCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
FinalLoadedCell = LoadedCell.dropna(axis=0)

# %%
FinalLoadedCell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 128 non-null    int64
#  1   Time                                128 non-null    object
#  2   Drive_Lat                           128 non-null    float64
#  3   Drive_Lon                           128 non-null    float64
#  4   Cell_lat                            128 non-null    float64
#  5   Cell_lon                            128 non-null    float64
#  6   Dis_Serving                         128 non-null    float64
#  7   Serving_Cell                        128 non-null    int64
#  8   Serving Cell RSRP                   128 non-null    float64
#  9   Serving Cell RSRQ                   128 non-null    float64
#  10  RS SINR Carrier 1                   128 non-null    float64
#  11  Serving Cell Channel RSSI           128 non-null    float64
#  12  CQI                                 128 non-null    int64
#  13  Throughput DL                       128 non-null    float64
#  14  Throughput UL                       128 non-null    float64
#  15  Rank Indicator                      128 non-null    int64
#  16  latitude_Cell_N1                    128 non-null    float64
#  17  longitude_Cell_N1                   128 non-null    float64
#  18  Distance_N1                         128 non-null    float64
#  19  Neighbor Cell Identity: N1          128 non-null    int64
#  20  Neighbor Cell RSRP: N1              128 non-null    float64
#  21  Neighbor Cell RSRQ: N1              128 non-null    float64
#  22  latitude_Cell_N2                    128 non-null    float64
#  23  longitude_Cell_N2                   128 non-null    float64
#  24  Distance_N2                         128 non-null    float64
#  25  Neighbor Cell Identity: N2          128 non-null    int64
#  26  Neighbor Cell RSRP: N2              128 non-null    float64
#  27  Neighbor Cell RSRQ: N2              128 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            128 non-null    float64
#  29  MAC UL Throughput (kbps)            128 non-null    float64
#  30  RLC Throughput DL (kbps)            128 non-null    float64
#  31  RLC Throughput UL (kbps)            128 non-null    float64
#  32  PDCCH Downlink Grant Count Current  128 non-null    int64
#  33  PDCCH Uplink Grant Count Current    128 non-null    int64
#  34  States                              128 non-null    object
# dtypes: float64(25), int64(8), object(2)
# memory usage: 35.1+ KB

# %%
FinalLoadedCell.describe()
# Out:
#                 ï»¿   Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  \
# count    128.000000  128.000000  128.000000  128.000000  128.000000
# mean    8385.578125   30.039614   30.969675   30.040927   30.971013
# std     4232.608450    0.004206    0.008248    0.008437    0.009181
# min      615.000000   30.030208   30.956015   30.008730   30.959722
# 25%     5586.750000   30.038012   30.963149   30.034190   30.963140
# 50%     8636.500000   30.039316   30.967864   30.040720   30.969330
# 75%    12639.250000   30.043566   30.974809   30.050030   30.978168
# max    14807.000000   30.044623   31.014428   30.050030   31.008840
#
#        Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count   128.000000    128.000000         128.000000         128.000000
# mean      0.683282    144.757812         -79.851563         -13.818750
# std       0.520606     99.307345           8.839835           2.229359
# min       0.338531     14.000000        -100.000000         -18.200001
# 25%       0.442779     76.000000         -86.724998         -15.200000
# 50%       0.629892    145.000000         -80.399998         -14.100000
# 75%       0.718876    148.250000         -74.975000         -12.775000
# max       3.797824    421.000000         -58.200001          -7.400000
#
#        RS SINR Carrier 1  ...  Distance_N2  Neighbor Cell Identity: N2  \
# count         128.000000  ...   128.000000                  128.000000
# mean            5.753906  ...     1.690062                  170.882812
# std             3.988722  ...     1.726977                  143.436431
# min            -3.200000  ...     0.225680                    3.000000
# 25%             2.875000  ...     0.435444                   59.750000
# 50%             5.850000  ...     1.023931                  152.000000
# 75%             8.625000  ...     3.299135                  191.000000
# max            16.400000  ...     8.289444                  501.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count              128.000000              128.000000
# mean               -90.822656              -25.360937
# std                  8.320492                3.853156
# min               -111.300003              -30.000000
# 25%                -96.525000              -28.925000
# 50%                -91.199997              -25.900000
# 75%                -86.400002              -22.775000
# max                -71.500000              -15.200000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count                128.000000                128.000000
# mean                  14.100547                126.784922
# std                    8.655461                 69.268965
# min                    0.000000                  0.000000
# 25%                   10.345000                 72.820002
# 50%                   12.920000                134.845001
# 75%                   17.892499                169.684994
# max                   54.310001                307.660004
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count                128.000000                128.000000
# mean                7651.207852                136.374378
# std                 6305.801870                102.210063
# min                    0.000000                  0.000000
# 25%                 3880.547486                 67.282499
# 50%                 6235.935059                125.695864
# 75%                 9668.969726                171.692505
# max                36643.968750                708.979981
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                          128.000000                        128.000000
# mean                          1227.195312                        837.203125
# std                            563.587735                        527.272933
# min                              0.000000                          2.000000
# 25%                            943.750000                        417.750000
# 50%                           1287.000000                        833.500000
# 75%                           1666.500000                       1293.750000
# max                           2007.000000                       1933.000000
#
# [8 rows x 33 columns]

# %%
FinalLoadedCell.isna().sum()
# Out:
# ï»¿                                   0
# Time                                  0
# Drive_Lat                             0
# Drive_Lon                             0
# Cell_lat                              0
# Cell_lon                              0
# Dis_Serving                           0
# Serving_Cell                          0
# Serving Cell RSRP                     0
# Serving Cell RSRQ                     0
# RS SINR Carrier 1                     0
# Serving Cell Channel RSSI             0
# CQI                                   0
# Throughput DL                         0
# Throughput UL                         0
# Rank Indicator                        0
# latitude_Cell_N1                      0
# longitude_Cell_N1                     0
# Distance_N1                           0
# Neighbor Cell Identity: N1            0
# Neighbor Cell RSRP: N1                0
# Neighbor Cell RSRQ: N1                0
# latitude_Cell_N2                      0
# longitude_Cell_N2                     0
# Distance_N2                           0
# Neighbor Cell Identity: N2            0
# Neighbor Cell RSRP: N2                0
# Neighbor Cell RSRQ: N2                0
# PDSCH BLER Carrier 1 (%)              0
# MAC UL Throughput (kbps)              0
# RLC Throughput DL (kbps)              0
# RLC Throughput UL (kbps)              0
# PDCCH Downlink Grant Count Current    0
# PDCCH Uplink Grant Count Current      0
# States                                0
# dtype: int64

# %%
FinalLoadedCell.head(5)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0  615  11:12:29 PM  30.041205  30.967895  30.04650  30.96940     0.606278
# 1  616  11:12:31 PM  30.041176  30.967834  30.04650  30.96940     0.610925
# 2  617  11:12:33 PM  30.041090  30.967821  30.04650  30.96940     0.620503
# 3  799  11:24:47 PM  30.037368  30.975265  30.04072  30.98725     1.212421
# 4  803  11:24:57 PM  30.037062  30.974340  30.04072  30.98725     1.307536
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  ...  \
# 0           143         -92.699997              -13.8  ...
# 1           143         -92.900002              -13.5  ...
# 2           143         -95.699997              -15.0  ...
# 3           285         -89.599998              -13.8  ...
# 4           285         -85.300003              -13.2  ...
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                          33             -100.699997              -24.900000
# 1                          15             -102.599998              -21.700001
# 2                          13             -103.099998              -22.200001
# 3                         152              -99.599998              -23.200001
# 4                         143              -96.800003              -23.600000
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                 23.389999                 65.860001
# 1                 22.610001                 46.130001
# 2                 25.030001                 53.980000
# 3                 12.300000                 99.250000
# 4                 12.290000                113.500000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               6201.459961                 93.320000
# 1               3518.719971                 46.750000
# 2               2921.870117                 49.660000
# 3              16246.019530                441.779999
# 4              13909.469730                203.350006
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                                1123                               230
# 1                                1142                               270
# 2                                1136                               139
# 3                                 805                               521
# 4                                 339                               396
#
#    States
# 0  Loaded
# 1  Loaded
# 2  Loaded
# 3  Loaded
# 4  Loaded
#
# [5 rows x 35 columns]

# %%
FinalLoadedCell.to_csv('FinalLoadedCellFiltered.csv', index=True)

# %% [markdown]
# Preparation

# %%
# data mining libaries
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, GridSearchCV, learning_curve
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sn
import matplotlib.pyplot as plt

#plot libaries
import plotly
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True) # to show plots in notebook

# online plotly
#from plotly.plotly import plot, iplot
#plotly.tools.set_credentials_file(username='XXXXXXXXXXXXXXX', api_key='XXXXXXXXXXXXXXX')

# offline plotly
from plotly.offline import plot, iplot

# do not show any warnings
import warnings
warnings.filterwarnings('ignore')

SEED = 42 # specify seed for reproducable results
pd.set_option('display.max_columns', None) # prevents abbreviation (with '...') of columns in prints
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# DATASET ANALYSIS

# %%
# load the dataset
df = pd.read_csv('FinalLoadedCellFiltered.csv')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# df = df.query('Throughput > 10000')
print("The dataset has %d rows and %d columns" % df.shape)
# Feature Selection
# df = df[['Serving Cell RSRP','Serving Cell Channel RSSI','Throughput UL','RLC Throughput DL (kbps)', 'MAC UL Throughput (kbps)', 'RS SINR Carrier 1', 'Serving Cell RSRQ','Throughput']]
# Out:
# The dataset has 128 rows and 36 columns

# %%
# df = df [['Serving Cell RSRP','Serving Cell Channel RSSI','Throughput UL','RLC Throughput DL (kbps)', 'MAC UL Throughput (kbps)', 'RS SINR Carrier 1', 'Serving Cell RSRQ','Throughput','PDSCH BLER Carrier 1 (%)','PDCCH Downlink Grant Count Current','PDCCH Uplink Grant Count Current','RLC Throughput UL (kbps)']]

# %%
df = df.drop('Unnamed: 0',axis=True)

# %%
feature_selection = df[['Serving_Cell','Serving Cell RSRP','Serving Cell RSRQ','Serving Cell Channel RSSI','Throughput DL','Throughput UL']]
import seaborn as sns
# Correlation Score
plt.figure(figsize=(12, 10))
correlation_matrix = feature_selection.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, cmap='coolwarm', annot=True,linewidths=0.01, )
plt.title("Correlation Matrix", size=25)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.describe()
# Out:
#                 ï»¿   Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  \
# count    128.000000  128.000000  128.000000  128.000000  128.000000
# mean    8385.578125   30.039614   30.969675   30.040927   30.971013
# std     4232.608450    0.004206    0.008248    0.008437    0.009181
# min      615.000000   30.030208   30.956015   30.008730   30.959722
# 25%     5586.750000   30.038012   30.963149   30.034190   30.963140
# 50%     8636.500000   30.039316   30.967864   30.040720   30.969330
# 75%    12639.250000   30.043566   30.974809   30.050030   30.978168
# max    14807.000000   30.044623   31.014428   30.050030   31.008840
#
#        Dis_Serving  Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  \
# count   128.000000    128.000000         128.000000         128.000000
# mean      0.683282    144.757812         -79.851563         -13.818750
# std       0.520606     99.307345           8.839835           2.229359
# min       0.338531     14.000000        -100.000000         -18.200001
# 25%       0.442779     76.000000         -86.724998         -15.200000
# 50%       0.629892    145.000000         -80.399998         -14.100000
# 75%       0.718876    148.250000         -74.975000         -12.775000
# max       3.797824    421.000000         -58.200001          -7.400000
#
#        RS SINR Carrier 1  Serving Cell Channel RSSI         CQI  \
# count         128.000000                 128.000000  128.000000
# mean            5.753906                 -49.060156    7.273438
# std             3.988722                   8.212832    1.478001
# min            -3.200000                 -70.800003    5.000000
# 25%             2.875000                 -54.624999    6.000000
# 50%             5.850000                 -48.500000    7.000000
# 75%             8.625000                 -43.425000    8.000000
# max            16.400000                 -30.600000   12.000000
#
#        Throughput DL  Throughput UL  Rank Indicator  latitude_Cell_N1  \
# count     128.000000     128.000000      128.000000        128.000000
# mean     6997.095175     682.224511        1.335938         30.040882
# std      3456.552898     433.219315        0.474173          0.004084
# min         0.020000       9.620000        1.000000         30.031055
# 25%      4491.365112     359.864998        1.000000         30.039874
# 50%      7575.495117     638.419165        1.000000         30.040550
# 75%      9570.877930    1016.007523        2.000000         30.045278
# max     14513.740230    1696.130005        2.000000         30.046230
#
#        longitude_Cell_N1  Distance_N1  Neighbor Cell Identity: N1  \
# count         128.000000   128.000000                   128.00000
# mean           30.969046     0.341767                   158.84375
# std             0.008525     0.125816                   128.95482
# min            30.959722     0.071751                    12.00000
# 25%            30.962790     0.291072                    62.00000
# 50%            30.971611     0.344828                   156.00000
# 75%            30.971949     0.381272                   158.00000
# max            31.017482     1.062748                   502.00000
#
#        Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  latitude_Cell_N2  \
# count              128.000000              128.000000        128.000000
# mean               -88.528906              -22.189062         30.032097
# std                  9.098214                3.123904          0.016720
# min               -111.199997              -30.000000         29.989903
# 25%                -94.975000              -24.050000         30.023237
# 50%                -89.100002              -21.799999         30.034190
# 75%                -82.350000              -20.675001         30.045278
# max                -67.300003              -14.100000         30.058100
#
#        longitude_Cell_N2  Distance_N2  Neighbor Cell Identity: N2  \
# count         128.000000   128.000000                  128.000000
# mean           30.973355     1.690062                  170.882812
# std             0.016730     1.726977                  143.436431
# min            30.940800     0.225680                    3.000000
# 25%            30.966194     0.435444                   59.750000
# 50%            30.971119     1.023931                  152.000000
# 75%            30.974717     3.299135                  191.000000
# max            31.071517     8.289444                  501.000000
#
#        Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# count              128.000000              128.000000
# mean               -90.822656              -25.360937
# std                  8.320492                3.853156
# min               -111.300003              -30.000000
# 25%                -96.525000              -28.925000
# 50%                -91.199997              -25.900000
# 75%                -86.400002              -22.775000
# max                -71.500000              -15.200000
#
#        PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# count                128.000000                128.000000
# mean                  14.100547                126.784922
# std                    8.655461                 69.268965
# min                    0.000000                  0.000000
# 25%                   10.345000                 72.820002
# 50%                   12.920000                134.845001
# 75%                   17.892499                169.684994
# max                   54.310001                307.660004
#
#        RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# count                128.000000                128.000000
# mean                7651.207852                136.374378
# std                 6305.801870                102.210063
# min                    0.000000                  0.000000
# 25%                 3880.547486                 67.282499
# 50%                 6235.935059                125.695864
# 75%                 9668.969726                171.692505
# max                36643.968750                708.979981
#
#        PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current
# count                          128.000000                        128.000000
# mean                          1227.195312                        837.203125
# std                            563.587735                        527.272933
# min                              0.000000                          2.000000
# 25%                            943.750000                        417.750000
# 50%                           1287.000000                        833.500000
# 75%                           1666.500000                       1293.750000
# max                           2007.000000                       1933.000000

# %%
df.columns
# Out:
# Index(['ï»¿', 'Time', 'Drive_Lat', 'Drive_Lon', 'Cell_lat', 'Cell_lon',
#        'Dis_Serving', 'Serving_Cell', 'Serving Cell RSRP', 'Serving Cell RSRQ',
#        'RS SINR Carrier 1', 'Serving Cell Channel RSSI', 'CQI',
#        'Throughput DL', 'Throughput UL', 'Rank Indicator', 'latitude_Cell_N1',
#        'longitude_Cell_N1', 'Distance_N1', 'Neighbor Cell Identity: N1',
#        'Neighbor Cell RSRP: N1', 'Neighbor Cell RSRQ: N1', 'latitude_Cell_N2',
#        'longitude_Cell_N2', 'Distance_N2', 'Neighbor Cell Identity: N2',
#        'Neighbor Cell RSRP: N2', 'Neighbor Cell RSRQ: N2',
#        'PDSCH BLER Carrier 1 (%)', 'MAC UL Throughput (kbps)',
#        'RLC Throughput DL (kbps)', 'RLC Throughput UL (kbps)',
#        'PDCCH Downlink Grant Count Current',
#        'PDCCH Uplink Grant Count Current', 'States'],
#       dtype='object')

# %%
count_nan = df.isna().sum().sum()
print ('Count of NaN/NULL values: ' + str(count_nan))
# Out:
# Count of NaN/NULL values: 0

# %%
df = df.dropna()

# %%
df.head(3)
# Out:
#    ï»¿         Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0  615  11:12:29 PM  30.041205  30.967895   30.0465   30.9694     0.606278
# 1  616  11:12:31 PM  30.041176  30.967834   30.0465   30.9694     0.610925
# 2  617  11:12:33 PM  30.041090  30.967821   30.0465   30.9694     0.620503
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           143         -92.699997              -13.8                4.1
# 1           143         -92.900002              -13.5                5.8
# 2           143         -95.699997              -15.0                2.3
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -58.400002    6    5691.549805     188.380005
# 1                 -59.000000    6    5554.290039     168.910004
# 2                 -60.500000    5    3930.479980     153.899994
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1         30.039874          30.971949     0.417352
# 1               1         30.039874          30.971949     0.421747
# 2               1         30.039874          30.971949     0.419717
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                         158             -100.300003              -21.000000
# 1                         158             -101.500000              -22.299999
# 2                         158             -102.699997              -21.799999
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0         30.013694          30.970627     3.070422
# 1         30.031055          30.971611     1.182659
# 2         30.031055          30.971611     1.173935
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                          33             -100.699997              -24.900000
# 1                          15             -102.599998              -21.700001
# 2                          13             -103.099998              -22.200001
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                 23.389999                 65.860001
# 1                 22.610001                 46.130001
# 2                 25.030001                 53.980000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               6201.459961                     93.32
# 1               3518.719971                     46.75
# 2               2921.870117                     49.66
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                                1123                               230
# 1                                1142                               270
# 2                                1136                               139
#
#    States
# 0  Loaded
# 1  Loaded
# 2  Loaded

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ï»¿                                 128 non-null    int64
#  1   Time                                128 non-null    object
#  2   Drive_Lat                           128 non-null    float64
#  3   Drive_Lon                           128 non-null    float64
#  4   Cell_lat                            128 non-null    float64
#  5   Cell_lon                            128 non-null    float64
#  6   Dis_Serving                         128 non-null    float64
#  7   Serving_Cell                        128 non-null    int64
#  8   Serving Cell RSRP                   128 non-null    float64
#  9   Serving Cell RSRQ                   128 non-null    float64
#  10  RS SINR Carrier 1                   128 non-null    float64
#  11  Serving Cell Channel RSSI           128 non-null    float64
#  12  CQI                                 128 non-null    int64
#  13  Throughput DL                       128 non-null    float64
#  14  Throughput UL                       128 non-null    float64
#  15  Rank Indicator                      128 non-null    int64
#  16  latitude_Cell_N1                    128 non-null    float64
#  17  longitude_Cell_N1                   128 non-null    float64
#  18  Distance_N1                         128 non-null    float64
#  19  Neighbor Cell Identity: N1          128 non-null    int64
#  20  Neighbor Cell RSRP: N1              128 non-null    float64
#  21  Neighbor Cell RSRQ: N1              128 non-null    float64
#  22  latitude_Cell_N2                    128 non-null    float64
#  23  longitude_Cell_N2                   128 non-null    float64
#  24  Distance_N2                         128 non-null    float64
#  25  Neighbor Cell Identity: N2          128 non-null    int64
#  26  Neighbor Cell RSRP: N2              128 non-null    float64
#  27  Neighbor Cell RSRQ: N2              128 non-null    float64
#  28  PDSCH BLER Carrier 1 (%)            128 non-null    float64
#  29  MAC UL Throughput (kbps)            128 non-null    float64
#  30  RLC Throughput DL (kbps)            128 non-null    float64
#  31  RLC Throughput UL (kbps)            128 non-null    float64
#  32  PDCCH Downlink Grant Count Current  128 non-null    int64
#  33  PDCCH Uplink Grant Count Current    128 non-null    int64
#  34  States                              128 non-null    object
# dtypes: float64(25), int64(8), object(2)
# memory usage: 35.1+ KB

# %%
df.drop(['ï»¿'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Time                                128 non-null    object
#  1   Drive_Lat                           128 non-null    float64
#  2   Drive_Lon                           128 non-null    float64
#  3   Cell_lat                            128 non-null    float64
#  4   Cell_lon                            128 non-null    float64
#  5   Dis_Serving                         128 non-null    float64
#  6   Serving_Cell                        128 non-null    int64
#  7   Serving Cell RSRP                   128 non-null    float64
#  8   Serving Cell RSRQ                   128 non-null    float64
#  9   RS SINR Carrier 1                   128 non-null    float64
#  10  Serving Cell Channel RSSI           128 non-null    float64
#  11  CQI                                 128 non-null    int64
#  12  Throughput DL                       128 non-null    float64
#  13  Throughput UL                       128 non-null    float64
#  14  Rank Indicator                      128 non-null    int64
#  15  latitude_Cell_N1                    128 non-null    float64
#  16  longitude_Cell_N1                   128 non-null    float64
#  17  Distance_N1                         128 non-null    float64
#  18  Neighbor Cell Identity: N1          128 non-null    int64
#  19  Neighbor Cell RSRP: N1              128 non-null    float64
#  20  Neighbor Cell RSRQ: N1              128 non-null    float64
#  21  latitude_Cell_N2                    128 non-null    float64
#  22  longitude_Cell_N2                   128 non-null    float64
#  23  Distance_N2                         128 non-null    float64
#  24  Neighbor Cell Identity: N2          128 non-null    int64
#  25  Neighbor Cell RSRP: N2              128 non-null    float64
#  26  Neighbor Cell RSRQ: N2              128 non-null    float64
#  27  PDSCH BLER Carrier 1 (%)            128 non-null    float64
#  28  MAC UL Throughput (kbps)            128 non-null    float64
#  29  RLC Throughput DL (kbps)            128 non-null    float64
#  30  RLC Throughput UL (kbps)            128 non-null    float64
#  31  PDCCH Downlink Grant Count Current  128 non-null    int64
#  32  PDCCH Uplink Grant Count Current    128 non-null    int64
#  33  States                              128 non-null    object
# dtypes: float64(25), int64(7), object(2)
# memory usage: 34.1+ KB

# %%
def preprocess_data(df):
    pre_df = df.copy()
    return pre_df

# %%
pre_df = preprocess_data(df)
pre_df.head(3)
# Out:
#           Time  Drive_Lat  Drive_Lon  Cell_lat  Cell_lon  Dis_Serving  \
# 0  11:12:29 PM  30.041205  30.967895   30.0465   30.9694     0.606278
# 1  11:12:31 PM  30.041176  30.967834   30.0465   30.9694     0.610925
# 2  11:12:33 PM  30.041090  30.967821   30.0465   30.9694     0.620503
#
#    Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# 0           143         -92.699997              -13.8                4.1
# 1           143         -92.900002              -13.5                5.8
# 2           143         -95.699997              -15.0                2.3
#
#    Serving Cell Channel RSSI  CQI  Throughput DL  Throughput UL  \
# 0                 -58.400002    6    5691.549805     188.380005
# 1                 -59.000000    6    5554.290039     168.910004
# 2                 -60.500000    5    3930.479980     153.899994
#
#    Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# 0               1         30.039874          30.971949     0.417352
# 1               1         30.039874          30.971949     0.421747
# 2               1         30.039874          30.971949     0.419717
#
#    Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  Neighbor Cell RSRQ: N1  \
# 0                         158             -100.300003              -21.000000
# 1                         158             -101.500000              -22.299999
# 2                         158             -102.699997              -21.799999
#
#    latitude_Cell_N2  longitude_Cell_N2  Distance_N2  \
# 0         30.013694          30.970627     3.070422
# 1         30.031055          30.971611     1.182659
# 2         30.031055          30.971611     1.173935
#
#    Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  Neighbor Cell RSRQ: N2  \
# 0                          33             -100.699997              -24.900000
# 1                          15             -102.599998              -21.700001
# 2                          13             -103.099998              -22.200001
#
#    PDSCH BLER Carrier 1 (%)  MAC UL Throughput (kbps)  \
# 0                 23.389999                 65.860001
# 1                 22.610001                 46.130001
# 2                 25.030001                 53.980000
#
#    RLC Throughput DL (kbps)  RLC Throughput UL (kbps)  \
# 0               6201.459961                     93.32
# 1               3518.719971                     46.75
# 2               2921.870117                     49.66
#
#    PDCCH Downlink Grant Count Current  PDCCH Uplink Grant Count Current  \
# 0                                1123                               230
# 1                                1142                               270
# 2                                1136                               139
#
#    States
# 0  Loaded
# 1  Loaded
# 2  Loaded

# %%
print("The dataset has %d rows and %d columns." % pre_df.shape)
# Out:
# The dataset has 128 rows and 34 columns.

# %%
pre_df.describe()
# Out:
#         Drive_Lat   Drive_Lon    Cell_lat    Cell_lon  Dis_Serving  \
# count  128.000000  128.000000  128.000000  128.000000   128.000000
# mean    30.039614   30.969675   30.040927   30.971013     0.683282
# std      0.004206    0.008248    0.008437    0.009181     0.520606
# min     30.030208   30.956015   30.008730   30.959722     0.338531
# 25%     30.038012   30.963149   30.034190   30.963140     0.442779
# 50%     30.039316   30.967864   30.040720   30.969330     0.629892
# 75%     30.043566   30.974809   30.050030   30.978168     0.718876
# max     30.044623   31.014428   30.050030   31.008840     3.797824
#
#        Serving_Cell  Serving Cell RSRP  Serving Cell RSRQ  RS SINR Carrier 1  \
# count    128.000000         128.000000         128.000000         128.000000
# mean     144.757812         -79.851563         -13.818750           5.753906
# std       99.307345           8.839835           2.229359           3.988722
# min       14.000000        -100.000000         -18.200001          -3.200000
# 25%       76.000000         -86.724998         -15.200000           2.875000
# 50%      145.000000         -80.399998         -14.100000           5.850000
# 75%      148.250000         -74.975000         -12.775000           8.625000
# max      421.000000         -58.200001          -7.400000          16.400000
#
#        Serving Cell Channel RSSI         CQI  Throughput DL  Throughput UL  \
# count                 128.000000  128.000000     128.000000     128.000000
# mean                  -49.060156    7.273438    6997.095175     682.224511
# std                     8.212832    1.478001    3456.552898     433.219315
# min                   -70.800003    5.000000       0.020000       9.620000
# 25%                   -54.624999    6.000000    4491.365112     359.864998
# 50%                   -48.500000    7.000000    7575.495117     638.419165
# 75%                   -43.425000    8.000000    9570.877930    1016.007523
# max                   -30.600000   12.000000   14513.740230    1696.130005
#
#        Rank Indicator  latitude_Cell_N1  longitude_Cell_N1  Distance_N1  \
# count      128.000000        128.000000         128.000000   128.000000
# mean         1.335938         30.040882          30.969046     0.341767
# std          0.474173          0.004084           0.008525     0.125816
# min          1.000000         30.031055          30.959722     0.071751
# 25%          1.000000         30.039874          30.962790     0.291072
# 50%          1.000000         30.040550          30.971611     0.344828
# 75%          2.000000         30.045278          30.971949     0.381272
# max          2.000000         30.046230          31.017482     1.062748
#
#        Neighbor Cell Identity: N1  Neighbor Cell RSRP: N1  \
# count                   128.00000              128.000000
# mean                    158.84375              -88.528906
# std                     128.95482                9.098214
# min                      12.00000             -111.199997
# 25%                      62.00000              -94.975000
# 50%                     156.00000              -89.100002
# 75%                     158.00000              -82.350000
# max                     502.00000              -67.300003
#
#        Neighbor Cell RSRQ: N1  latitude_Cell_N2  longitude_Cell_N2  \
# count              128.000000        128.000000         128.000000
# mean               -22.189062         30.032097          30.973355
# std                  3.123904          0.016720           0.016730
# min                -30.000000         29.989903          30.940800
# 25%                -24.050000         30.023237          30.966194
# 50%                -21.799999         30.034190          30.971119
# 75%                -20.675001         30.045278          30.974717
# max                -14.100000         30.058100          31.071517
#
#        Distance_N2  Neighbor Cell Identity: N2  Neighbor Cell RSRP: N2  \
# count   128.000000                  128.000000              128.000000
# mean      1.690062                  170.882812              -90.822656
# std       1.726977                  143.436431                8.320492
# min       0.225680                    3.000000             -111.300003
# 25%       0.435444                   59.750000              -96.525000
# 50%       1.023931                  152.000000              -91.199997
# 75%       3.299135                  191.000000              -86.400002
# max       8.289444                  501.000000              -71.500000
#
#        Neighbor Cell RSRQ: N2  PDSCH BLER Carrier 1 (%)  \
# count              128.000000                128.000000
# mean               -25.360937                 14.100547
# std                  3.853156                  8.655461
# min                -30.000000                  0.000000
# 25%                -28.925000                 10.345000
# 50%                -25.900000                 12.920000
# 75%                -22.775000                 17.892499
# max                -15.200000                 54.310001
#
#        MAC UL Throughput (kbps)  RLC Throughput DL (kbps)  \
# count                128.000000                128.000000
# mean                 126.784922               7651.207852
# std                   69.268965               6305.801870
# min                    0.000000                  0.000000
# 25%                   72.820002               3880.547486
# 50%                  134.845001               6235.935059
# 75%                  169.684994               9668.969726
# max                  307.660004              36643.968750
#
#        RLC Throughput UL (kbps)  PDCCH Downlink Grant Count Current  \
# count                128.000000                          128.000000
# mean                 136.374378                         1227.195312
# std                  102.210063                          563.587735
# min                    0.000000                            0.000000
# 25%                   67.282499                          943.750000
# 50%                  125.695864                         1287.000000
# 75%                  171.692505                         1666.500000
# max                  708.979981                         2007.000000
#
#        PDCCH Uplink Grant Count Current
# count                        128.000000
# mean                         837.203125
# std                          527.272933
# min                            2.000000
# 25%                          417.750000
# 50%                          833.500000
# 75%                         1293.750000
# max                         1933.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Time                                128 non-null    object
#  1   Drive_Lat                           128 non-null    float64
#  2   Drive_Lon                           128 non-null    float64
#  3   Cell_lat                            128 non-null    float64
#  4   Cell_lon                            128 non-null    float64
#  5   Dis_Serving                         128 non-null    float64
#  6   Serving_Cell                        128 non-null    int64
#  7   Serving Cell RSRP                   128 non-null    float64
#  8   Serving Cell RSRQ                   128 non-null    float64
#  9   RS SINR Carrier 1                   128 non-null    float64
#  10  Serving Cell Channel RSSI           128 non-null    float64
#  11  CQI                                 128 non-null    int64
#  12  Throughput DL                       128 non-null    float64
#  13  Throughput UL                       128 non-null    float64
#  14  Rank Indicator                      128 non-null    int64
#  15  latitude_Cell_N1                    128 non-null    float64
#  16  longitude_Cell_N1                   128 non-null    float64
#  17  Distance_N1                         128 non-null    float64
#  18  Neighbor Cell Identity: N1          128 non-null    int64
#  19  Neighbor Cell RSRP: N1              128 non-null    float64
#  20  Neighbor Cell RSRQ: N1              128 non-null    float64
#  21  latitude_Cell_N2                    128 non-null    float64
#  22  longitude_Cell_N2                   128 non-null    float64
#  23  Distance_N2                         128 non-null    float64
#  24  Neighbor Cell Identity: N2          128 non-null    int64
#  25  Neighbor Cell RSRP: N2              128 non-null    float64
#  26  Neighbor Cell RSRQ: N2              128 non-null    float64
#  27  PDSCH BLER Carrier 1 (%)            128 non-null    float64
#  28  MAC UL Throughput (kbps)            128 non-null    float64
#  29  RLC Throughput DL (kbps)            128 non-null    float64
#  30  RLC Throughput UL (kbps)            128 non-null    float64
#  31  PDCCH Downlink Grant Count Current  128 non-null    int64
#  32  PDCCH Uplink Grant Count Current    128 non-null    int64
#  33  States                              128 non-null    object
# dtypes: float64(25), int64(7), object(2)
# memory usage: 34.1+ KB

# %% [markdown]
#  DATA VISUALIZATION

# %%
pre_df.columns
# Out:
# Index(['Time', 'Drive_Lat', 'Drive_Lon', 'Cell_lat', 'Cell_lon', 'Dis_Serving',
#        'Serving_Cell', 'Serving Cell RSRP', 'Serving Cell RSRQ',
#        'RS SINR Carrier 1', 'Serving Cell Channel RSSI', 'CQI',
#        'Throughput DL', 'Throughput UL', 'Rank Indicator', 'latitude_Cell_N1',
#        'longitude_Cell_N1', 'Distance_N1', 'Neighbor Cell Identity: N1',
#        'Neighbor Cell RSRP: N1', 'Neighbor Cell RSRQ: N1', 'latitude_Cell_N2',
#        'longitude_Cell_N2', 'Distance_N2', 'Neighbor Cell Identity: N2',
#        'Neighbor Cell RSRP: N2', 'Neighbor Cell RSRQ: N2',
#        'PDSCH BLER Carrier 1 (%)', 'MAC UL Throughput (kbps)',
#        'RLC Throughput DL (kbps)', 'RLC Throughput UL (kbps)',
#        'PDCCH Downlink Grant Count Current',
#        'PDCCH Uplink Grant Count Current', 'States'],
#       dtype='object')

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=pre_df['Throughput DL'])
# Out:
# <Axes: xlabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
dfplot = df
sns.scatterplot(data=dfplot,x='Serving Cell RSRP',y='Throughput DL')
# Out:
# <Axes: xlabel='Serving Cell RSRP', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='Serving Cell RSRQ',y='Throughput DL')
# Out:
# <Axes: xlabel='Serving Cell RSRQ', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='RS SINR Carrier 1',y='Throughput DL')
# Out:
# <Axes: xlabel='RS SINR Carrier 1', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='Throughput UL',y='Throughput DL')
# Out:
# <Axes: xlabel='Throughput UL', ylabel='Throughput DL'>

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=dfplot,x='CQI',y='Throughput DL')
# Out:
# <Axes: xlabel='CQI', ylabel='Throughput DL'>

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(8, 5))
sn.boxplot(x=pre_df['Throughput DL'])
# Out:
# <Axes: xlabel='Throughput DL'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.displot(pre_df['Throughput DL'])
sns.displot(pre_df['Serving Cell RSRP'])
sns.displot(pre_df['Serving Cell RSRQ'])
sns.displot(pre_df['RS SINR Carrier 1'])
sns.displot(pre_df['Throughput UL'])

# %%
# pre_df.hist(bins=50, figsize=(20,15))
# sns.pairplot(pre_df)

# %%
pre_df.hist(bins=50, figsize=(20,15))
sns.distplot(kde=True,norm_hist=True,bins=50,rug=True)
# Out:
# <Axes: >

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 7
plt.rcParams["figure.figsize"] = fig_size

# %%
ax = sn.scatterplot(x=pre_df['Serving Cell Channel RSSI'], y=pre_df['RS SINR Carrier 1'], s=100,alpha=0.1, palette="icefire", hue=pre_df['Throughput DL'])
plt.title('DL-bitrate relationship between SINR and RSSI')
# Remove the legend and add a colorbar
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# Create a figure and axes for subplots (3 rows, 3 columns)
fig, axs = plt.subplots(3, 3, figsize=(12, 12))

# Scatter plot for Throughput DL
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Throughput DL'], ax=axs[0, 0])
axs[0, 0].set_title('Throughput DL (Mbps)')

# Scatter plot for Throughput UL
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['Throughput UL'], ax=axs[0, 1])
axs[0, 1].set_title('Throughput UL (Mbps)')

# Scatter plot for CQI
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['CQI'], ax=axs[0, 2])
axs[0, 2].set_title('CQI')

# Scatter plot for PDSCH BLER Carrier 1 (%)
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['PDSCH BLER Carrier 1 (%)'], ax=axs[1, 0])
axs[1, 0].set_title('PDSCH BLER Carrier 1 (%)')

# Scatter plot for MAC UL Throughput (kbps)
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['MAC UL Throughput (kbps)'], ax=axs[1, 1])
axs[1, 1].set_title('MAC UL Throughput (kbps)')

# Scatter plot for RLC Throughput DL (kbps)
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['RLC Throughput DL (kbps)'], ax=axs[1, 2])
axs[1, 2].set_title('RLC Throughput DL (kbps)')

# Scatter plot for RLC Throughput UL (kbps)
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['RLC Throughput UL (kbps)'], ax=axs[2, 0])
axs[2, 0].set_title('RLC Throughput UL (kbps)')

# Scatter plot for PDCCH Downlink Grant Count Current
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['PDCCH Downlink Grant Count Current'], ax=axs[2, 1])
axs[2, 1].set_title('PDCCH Downlink Grant Count Current')

# Scatter plot for PDCCH Uplink Grant Count Current
sn.scatterplot(x=pre_df['Drive_Lon'], y=pre_df['Drive_Lat'], s=50, alpha=1, palette="Spectral", hue=pre_df['PDCCH Uplink Grant Count Current'], ax=axs[2, 2])
axs[2, 2].set_title('PDCCH Uplink Grant Count Current')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()


# Save the figure
fig.savefig("LoadedCell.png")
